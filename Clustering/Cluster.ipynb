# %%
categories = {
                "Selling" :['purchase',
                             'bargain',
                             'steal',
                            'discount',
                            'low-price',
                            'save',
                            'cheap',
                            'order',
                            'place',
                            'delivery',
                            'special',
                            'offer',
                            'limited',
                            'stock',
                            'available',
                            'whatsapp',
                            'women',
                            'woman',
                            'size',
                            'male',
                            'suit',
                            'price',
                            'guarantee',
                            'watch',
                            'cloth',
                            'season',
                             'bribe',
                             'corrupt',
                             'sell',
                             'purchased',
                             'acquire',
                             'purchasing',
                             'selling',
                             'Invest',
                             'purchases',
                             'sale',
                             'procure',
                             'pay',
                             'offer',
                             'redeem',
                             'afford',
                             'obtain',
                             'buyback',
                             'grab',
                             'spend',
                             'consume',
                             'eat',
                             'acquiring',
                             'repurchase',
                             'acquires',
                             'purchaser',
                             'give',
                             'procures',
                             'get',
                             'offering',
                             'procured',
                             'buyout',
                             'paying',
                             'shop',
                             'supply',
                             'develop',
                             'market',
                             'procuring',
                             'shopping',
                             'earn'],
    
                
                "Pornography" : ['porno',
                                 'pornography',
                                 'pornographic',
                                 'sex',
                                 'flirt',
                                 'erotic',
                                 'prostitution',
                                 'movie',
                                 'salacious',
                                 'mags',
                                 'interracial',
                                 'dirty',
                                 'scam',
                                 'child',
                                 'vice',
                                 'erotica',
                                 'pornstar',
                                 'smut',
                                 'xxx',
                                 'nude',
                                 'hentai',
                                 'blowjob',
                                 'cybersex',
                                 'pornographer',
                                 'masturbation',
                                 'raunchy',
                                 'porny',
                                 'gangbang',
                                 'pussy',
                                 'bestiality',
                                 'horny',
                                 'fetish',
                                 'Bdsm',
                                 'niteflirt',
                                 'Titty',
                                 'gay',
                                 'kinky',
                                 'twink',
                                 'nudist',
                                 'Dick',
                                 'wank',
                                 'striptease',
                                 'kiddie porn',
                                 'porn',
                                 'pornocracy'],
    
                "Social Media Promotion" : ['dit',
                                            'vine',
                                            'youtube',
                                            'video',
                                            'pic',
                                            'clip',
                                            'vlog',
                                            'site',
                                             'joke',
                                             'album',
                                             'twitter',
                                             'myspace',
                                             'youtube',
                                             'Google',
                                             'retweet',
                                             'blog',
                                             'yahoo',
                                             'blogging',
                                            'channel',
                                            'retweet',
                                            'drop',
                                             'microblogging',
                                             'webpage',
                                             'microblog',
                                             'skype',
                                             'twitterer',
                                             'website',
                                             'homepage',
                                             'internet',
                                             'email',
                                            'subscribe',
                                            'follow',
                                            'like',
                                            'justin',
                                             'widget',
                                             'web',
                                             'chatroom',
                                             'webmaster',
                                             'Friendster',
                                             'friending',
                                             'tweets'
                                             ],
    
    
                "Contact Us" : ["call",
                          "voice mail",
                          "vmail",
                            "call",
                          "text",
                          "contact",
                          "message",
                          "email",
                          "sms",
                          "txt",
                          "voicemail",
                          "msg",
                          "messenger",
                          "mail",
                          "gmail",
                            "nearest",
                                'contact',
                                 ],
    "Banking": ['insurance',
                'loan',
                'interest',
                'return',
                'mutual',
                'fund',
                'bank',
                'invest',
                'access',
                'roi',
                'crore',
                'risk',
                'saving',
                'deposit',
                'liquid',
                'withdraw',
                'finance',
                'account',
                'currency',
                'monetary',
                'money',
                'share',
                'shareholder'
                
               ],
    "Politics": [
        "Trump",
        "antifa",
        "party",
        "republican",
        "republic",
        "congress",
        "democracy",
        "vote",
        "democrat",
        "candidate",
        "election",
        "poll",
        "right",
        "ballot",
        "electoral",
        "elect",
        "senate",
        "president",
        "realdonaldtrump",
        "power",
        "run",
        "office",
        "campaign",
        "political"
        
    ],
    "MOOCs": [
        "online",
        "course",
        "tutorial",
        "class",
        "track",
        "curriculum",
        "instructor",
        "teacher",
        "professor",
        "teach",
        "teaching",
        "syllabus",
        "learn",
        "degree",
        "certificate",
        "certification",
        "study",
        "lesson",
        "school",
        "join",
        "train",
        "training",
        "year"
    ],
    
    "Appointment": [
                    "book",
                    "home",
                    "appointment",
                    "visit",
                    "timing",
                    "doorstep",
                    "schedule",
                    "experience",
                    "experienced",
                    "date",
                    "reschedule",
                    "date"
    ],
    
    "Racism": [
                "black",
                "white",
                "race",
                "color",
                "skin",
                "equality",
                "racist",
                "exclusion",
                "bias",
                "privilege",
                "discrimination",
                "supremacy",
                "issue",
                "favoritism",
                "racism"
    ],
    
    "Legal": [
                "law",
                "legal",
                "advocate",
                "attorney",
                "lawyer",
                 'solicitor',
                 'attorneys',
                 'counsel',
                 'litigator',
                 'barrister',
                 'prosecutor',
                 'counsels',
                 'solicitors',
                 'advocate',
                 'legal',
                 'practitioner',
                 'jurist',
                 'counselor',
                 'barristers',
                 'defender',
                 'law',
                 'ombudsman',
                 'jurists',
                 'notary',
                 'counsellor',
                 'advocacy',
                 'representation',
                 'advocates',
                 'supporter',
                 'lawman',
                 'defence',
                 'council',
                 'privilege',
                 'champion',
                 'bar',
                 'conversation',
                 'defensor',
                 'avocado',
                 'Reese',
                 'attorney-at-law',
                 'avvocato',
                 'barrister-at-law',
                 'Rechtsanwalt',
                 'solicitor-general',
                 'avocados',
                 'solicitor',
                 'attorneys',
                 'counsel',
                 'litigator',
                 'barrister',
                 'prosecutor',
                 'counsels',
                 'solicitors',
                 'advocate',
                 'legal',
                 'practitioner',
                 'jurist',
                 'counselor',
                 'barristers',
                 'defender',
                 'law',
                 'ombudsman',
                 'jurists',
                 'notary',
                 'counsellor',
                 'advocacy',
                 'representation',
                 'advocates',
                 'supporter',
                 'lawman',
                 'defence',
                 'council',
                 'privilege',
                 'champion',
                 'bar',
                 'conversation',
                'crime',
                'criminal',
                 'defensor',
                 'avocado',
                 'Reese',
                 'attorney-at-law',
                 'avvocato',
                 'barrister-at-law',
                 'Rechtsanwalt',
                 'solicitor-general',
                 'avocados',
                 'paralegal'
    ],
    "Give Away": [
        "giveaway",
        "follow",
        "win",
        "lucky",
        "draw",
        "jackpot",
        "limited",
        "offer",
        "share",
        "freebie",
        "raffle",
        "goodie",
        "contest",
        "bonanza",
        "voucher",
        "swag",
        "coupon",
        "gift",
        "winner",
        "accouncement",
        "announce",
        "free",
        "deadline",
    ]
    
                }

import pandas as pd

# %%
for k, v in categories.items():
    categories[k]=" ".join(categories[k])

# %%
df_cat = pd.DataFrame.from_dict(categories,orient='index')

# %%
df_cat[0]
# Out:
# Selling                   purchase bargain steal discount low-price save...
# Pornography               porno pornography pornographic sex flirt eroti...
# Social Media Promotion    dit vine youtube video pic clip vlog site joke...
# Contact Us                call voice mail vmail call text contact messag...
# Banking                   insurance loan interest return mutual fund ban...
# Politics                  Trump antifa party republican republic congres...
# MOOCs                     online course tutorial class track curriculum ...
# Appointment               book home appointment visit timing doorstep sc...
# Racism                    black white race color skin equality racist ex...
# Legal                     law legal advocate attorney lawyer solicitor a...
# Give Away                 giveaway follow win lucky draw jackpot limited...
# Name: 0, dtype: object

# %%
import pandas as pd
import re
import numpy as np
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, chi2

# %%
import pymongo

client = pymongo.MongoClient()
db = getattr(client, 'filtered_posts')
coll = db.posts
print(db.list_collection_names())
# Out:
# ['new_posts']

# %%
posts = db.new_posts
curs= posts.find()

# %%
lis = []
for i, doc in enumerate(curs):
#     print(doc['content'])
    lis.append(doc['content'])
    #######  SAFETY FOR DEVELOPMENT #######
#     if i > 4:
#         break;
    #######################################

# %%
dic = {}
dic['content'] = lis
df = pd.DataFrame(dic)

# %%
df
# Out:
#                                                   content
# 0                           백퍼센트 Teaser Photo II 20180726
# 1       New Message Pluck Sound[ad_1]https://s3.envato...
# 2       $3 Fries Vs. $100 Fries Líder Toni 43996647900...
# 3       Since I have to practice itI putting 50% off m...
# 4       Ich denke, man kann sagen, dass der größte Tei...
# 5       https://osarobohenry.files.wordpress.com/2017/...
# 6       https://osarobohenry.files.wordpress.com/2017/...
# 7       New Post has been published on https://www.dow...
# 8       #Kişisel #Mutluluk ve hayallerdeki eşten olan ...
# 9       Agora nossa #consultoria traz #economia e #red...
# 10      Agora nossa #consultoria traz #economia e #red...
# 11      Agora nossa #consultoria traz #economia e #red...
# 12                   #инфроструктура#WhatsApp+79284032912
# 13      Werden dir andere schnell wichtig?\n.\n.\n.\n....
# 14                #автозаполоненнось#WhatsApp+79284032912
# ...

# %%
stemmer = SnowballStemmer('english')
words = stopwords.words('english')

# %%
df['cleaned'] = df['content'].apply(lambda x: " ".join([stemmer.stem(i) for i in re.sub("[^a-zA-Z]", " ", x).split() if i not in words]))

# %%
df
# Out:
#                                                   content  \
# 0                           백퍼센트 Teaser Photo II 20180726
# 1       New Message Pluck Sound[ad_1]https://s3.envato...
# 2       $3 Fries Vs. $100 Fries Líder Toni 43996647900...
# 3       Since I have to practice itI putting 50% off m...
# 4       Ich denke, man kann sagen, dass der größte Tei...
# 5       https://osarobohenry.files.wordpress.com/2017/...
# 6       https://osarobohenry.files.wordpress.com/2017/...
# 7       New Post has been published on https://www.dow...
# 8       #Kişisel #Mutluluk ve hayallerdeki eşten olan ...
# 9       Agora nossa #consultoria traz #economia e #red...
# 10      Agora nossa #consultoria traz #economia e #red...
# 11      Agora nossa #consultoria traz #economia e #red...
# 12                   #инфроструктура#WhatsApp+79284032912
# 13      Werden dir andere schnell wichtig?\n.\n.\n.\n....
# 14                #автозаполоненнось#WhatsApp+79284032912
# ...

# %%
df_cat['cleaned'] = df_cat[0].apply(lambda x: " ".join([stemmer.stem(i) for i in re.sub("[^a-zA-Z]", " ", x).split() if i not in words]))

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vect2 = CountVectorizer()
print(df_cat['cleaned'][0])
count_vect2.fit_transform([df_cat['cleaned'][0]])
# Out:
# purchas bargain steal discount low price save cheap order place deliveri special offer limit stock avail whatsapp women woman size male suit price guarante watch cloth season bribe corrupt sell purchas acquir purchas sell invest purchas sale procur pay offer redeem afford obtain buyback grab spend consum eat acquir repurchas acquir purchas give procur get offer procur buyout pay shop suppli develop market procur shop earn
# <1x51 sparse matrix of type '<class 'numpy.int64'>'
# 	with 51 stored elements in Compressed Sparse Row format>

# %%
count_vect = CountVectorizer()
df_cat['vect'] = count_vect.fit_transform(df_cat['cleaned'])

# %%
import nltk
import string
nltk.download('wordnet') # first-time use only
lemmer = nltk.stem.WordNetLemmatizer()
def LemTokens(tokens):
    return [lemmer.lemmatize(token) for token in tokens]
remove_punct_dict = dict((ord(punct), None) for punct in string.punctuation)
def LemNormalize(text):
     return LemTokens(nltk.word_tokenize(text.lower().translate(remove_punct_dict)))
# Out:
# [nltk_data] Downloading package wordnet to /home/kali/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
LemVectorizer = CountVectorizer(tokenizer=LemNormalize)
LemVectorizer.fit_transform(df_cat['cleaned'])
# Out:
# <11x288 sparse matrix of type '<class 'numpy.int64'>'
# 	with 296 stored elements in Compressed Sparse Row format>

# %%
WORD = re.compile(r'\w+')

# %%
def get_cosine(vec1, vec2):
    intersection = set(vec1.keys()) & set(vec2.keys())
    numerator = sum([vec1[x] * vec2[x] for x in intersection])

    sum1 = sum([vec1[x]**2 for x in vec1.keys()])
    sum2 = sum([vec2[x]**2 for x in vec2.keys()])
    denominator = math.sqrt(sum1) * math.sqrt(sum2)

    if not denominator:
        return 0.0
    else:
        return float(numerator) / denominator

def text_to_vector(text):
    words = WORD.findall(text)
    return Counter(words)

# %%
client = pymongo.MongoClient()
db = client.clustered_data
coll2 = db.posts

# %%
from collections import Counter
import math

new_cursor = posts.find()
count  = 0
for post, db_post in zip(df['cleaned'], new_cursor):
    vector2 = text_to_vector(post)
    max_similarity = 0
    target_category = 'no category'
    for category, item in categories.items():
        vector1 = text_to_vector(item)
        cosine = get_cosine(vector1, vector2)
        if cosine > max_similarity:
            max_similarity = cosine
            target_category = category
#     print()
#     print (str(max_similarity) +'||' + target_category + '||' + post)
    if max_similarity < 0.02:
        target_category = 'Other'
        
    # Insert into new db
    db_post['category'] = target_category
    try:
        # print("reached")
        coll2.insert(db_post)  # and insert
    except pymongo.errors.DuplicateKeyError:  # Except if it's already there
        pass
print("Complete")
#     count += 1
#     if count >100:
#         break
# Out:
# /home/kali/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:25: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# Complete
