# %%
categories = {
                "Selling" :['purchase',
                             'bargain',
                             'steal',
                             'bribe',
                             'corrupt',
                             'sell',
                             'purchased',
                             'acquire',
                             'purchasing',
                             'selling',
                             'Invest',
                             'purchases',
                             'sale',
                             'procure',
                             'pay',
                             'offer',
                             'redeem',
                             'afford',
                             'obtain',
                             'buyback',
                             'grab',
                             'spend',
                             'consume',
                             'eat',
                             'acquiring',
                             'repurchase',
                             'acquires',
                             'purchaser',
                             'give',
                             'procures',
                             'get',
                             'offering',
                             'procured',
                             'buyout',
                             'paying',
                             'shop',
                             'supply',
                             'develop',
                             'market',
                             'procuring',
                             'shopping',
                             'earn'],
    
                "Cyber Hacking" : ['hack',
                                 'drudge',
                                 'hacking',
                                 'cyber',
                                 'intruder',
                                 'attacker',
                                 'infiltrator',
                                 'pirating',
                                 'pirate',
                                 'intrusion',
                                 'addict',
                                 'tech',
                                 'cracker',
                                 'bogey',
                                 'tenant',
                                 'malware',
                                 'phishing',
                                 'spammer',
                                 'phisher',
                                 'Trojan',
                                 'Trojan Horse',
                                 'scammer',
                                 'cybercrime',
                                 'computer',
                                 'bot',
                                 'prankster',
                                 'thief',
                                 'programmer',
                                 'burglar',
                                 'stalker',
                                 'honeypot',
                                 'cyberwar',
                                 'counterfeiter',
                                 'spy',
                                 'techie',
                                 'cyberspace',
                                 'identity theft',
                                 'geek',
                                 'espionage',
                                 'vulnerability',
                                 'firewall',
                                 'spambot'],
                "Pornography" : ['porno',
                                 'pornography',
                                 'pornographic',
                                 'sex',
                                 'erotic',
                                 'prostitution',
                                 'movie',
                                 'salacious',
                                 'mags',
                                 'interracial',
                                 'dirty',
                                 'scam',
                                 'child',
                                 'vice',
                                 'erotica',
                                 'pornstar',
                                 'smut',
                                 'xxx',
                                 'nude',
                                 'hentai',
                                 'blowjob',
                                 'cybersex',
                                 'pornographer',
                                 'masturbation',
                                 'raunchy',
                                 'porny',
                                 'gangbang',
                                 'pussy',
                                 'bestiality',
                                 'horny',
                                 'fetish',
                                 'Bdsm',
                                 'Titty',
                                 'gay',
                                 'kinky',
                                 'twink',
                                 'nudist',
                                 'Dick',
                                 'wank',
                                 'striptease',
                                 'kiddie porn',
                                 'porn',
                                 'pornocracy'],
                "Video Promotion" : ['dit', 'vine', 'youtube', 'video', 'pic', 'clip', 'vlog'],
                "call" : ["call","voice mail","vmail","call","text"],
                }
