# %%
import numpy as np
import re

# %%
import pymongo
import pycountry
import phonenumbers
from phonenumbers.phonenumberutil import region_code_for_country_code
from phonenumbers.phonenumberutil import region_code_for_number

### -h ds241121.mlab.com:41121 -d social_data -c posts -u user -p pass1234 --file test.json

# connection_params = {
#     'user': 'user',
#     'password': 'password',
#     'host': 'localhost',
#     'port': 27017,
#     'namespace': 'social_data',
# }

# connection = pymongo.MongoClient(
#     'mongodb://{user}:{password}@{host}:'
#     '{port}/{namespace}'.format(**connection_params)
# )

# db = connection.social_data
client = pymongo.MongoClient()
db = getattr(client, 'social_data')
coll = db.posts
print(db.list_collection_names())
# Out:
# ['posts']

# %%
mapping = {country.alpha_2: country.name for country in pycountry.countries}

# %%
for i in range(240):
    list_to_be_fill_with_documents=[]

    curs=db.posts.find().limit(500000).skip(500000*i)
    
    client = pymongo.MongoClient()
    db_new = client.filtered_posts
    coll = db_new.new_posts

    for doc in curs:
        list_to_be_fill_with_documents.append(doc)
    
    print(len(list_to_be_fill_with_documents))
    
    ####################################################33
    
    np_arr = np.asarray(list_to_be_fill_with_documents)
    
    arr = []
    count_ins = 0
    count_dup = 0
    r1 = r'(\d{1,5}-\d{3,5}-\d{3,7})' 
    r1p = r'(\+\d{1,5}-\d{3,5}-\d{3,7})' 

    r2 = r'\(?[\d]{3}\)?[-\s]?[\d]{3}[-\s]?[\d]{3,6}'
    r2p = r'\+\(?[\d]{3}\)?[-\s]?[\d]{3}[-\s]?[\d]{3,6}[-\s]?[\d]{3,6}'
    r = r'(\d[\d\s-]{5,13}\d{2,4})'

    rp = r'(\+\d[\d\s-]{5,13}\d{2,4})'
    r3 = r'(\(\d{3,5}\)[-\s\d]\d{2,5}[-\s\d]\d{2,6})'  
    r3p = r'(\+\(\d{3,5}\)[-\s\d]\d{2,5}[-\s\d]\d{2,6})'  

    # r2 = r'(1\s?)?((\([0-9]{3}\))|[0-9]{3})[\s\-]?[\0-9]{3}[\s\-]?[0-9]{4}'
    #d dddddd, dddddddd,d        
    # r2= r'\$ *\d+[\.]*\d+|\d+[\.]*\d+\$'
    # r3= r'^\d+\s|\s\d+\s|\s\d+$'
    count = 0
    countp = 0
    count_arr = [0]*8
    for i,doc in enumerate(np_arr):
        content = doc['content']
        a = re.findall(r2, content)
        b = re.findall(r1, content)
        c = re.findall(r, content)
        d = re.findall(r3,content)
        ap = re.findall(r2p, content)
        bp = re.findall(r1p, content)
        cp = re.findall(rp, content)
        dp = re.findall(r3p,content)
        # e = re.findall(r'(\d[\d ]{5,13}\d{2})', content)

    #     if len(e) > 0:
    #         count2 += 1
    #         # print(e)

        if len(ap)>0:
            countp += 1
            nums = ''
            for elem in ap:
                try:
                    region = region_code_for_number(phonenumbers.parse(elem))
                except:
                    print("$$$$$$ " + elem + "$$$$$")
                    continue
                count_arr[0] += 1

                nums += elem + ','
                if region is None:
                    print(doc['content'])
                    print("###############")
                    print(ap)
                else:
                    if region == '001':
                        continue
                    arr.append(mapping[region])
                    doc['region'] = mapping[region]
                    doc['numbers'] = nums

                    try:
                        coll.insert(doc)  # and insert
                        count_ins += 1
                    except pymongo.errors.DuplicateKeyError:  # Except if it's already there
                        count_dup += 1
            continue



        if len(cp)>0:
            countp += 1
            nums = ''
            for elem in cp:
                try:
                    region = region_code_for_number(phonenumbers.parse(elem))
                except:
                    print("$$$$$$ " + elem + "$$$$$")
                    continue
                nums += elem + ','
                if region is None:
                    print(doc['content'])
                    print("###############")
                    print(cp)
                else:
                    if region == '001':
                        continue
                    arr.append(mapping[region])
                    doc['region'] = mapping[region]
                    doc['numbers'] = nums
                    try:
                        coll.insert(doc)  # and insert
                        count_ins += 1
                    except pymongo.errors.DuplicateKeyError:  # Except if it's already there
                        count_dup += 1
            count_arr[1] += 1

            continue

        if len(dp)>0:
            countp += 1
            nums = ''
            for elem in dp:
                try:
                    region = region_code_for_number(phonenumbers.parse(elem))
                except:
                    print("$$$$$$ " + elem + "$$$$$")
                    continue
                nums += elem + ','
                if region is None:
                    print(doc['content'])
                    doc['nums'] = nums
                    print("###############")
                    print(dp)
                else:
                    if region == '001':
                        continue
                    arr.append(mapping[region])
                    doc['region'] = mapping[region]
                    doc['numbers'] = nums
                    try:
                        coll.insert(doc)  # and insert
                        count_ins += 1
                    except pymongo.errors.DuplicateKeyError:  # Except if it's already there
                        count_dup += 1
            count_arr[2] += 1
            continue


        if len(bp)>0:
            countp += 1
            nums = ''
            for elem in bp:
                try:
                    region = region_code_for_number(phonenumbers.parse(elem))
                except:
                    print("$$$$$$ " + elem + "$$$$$")
                    continue
                nums += elem + ','
                if region is None:
                    print(doc['content'])
                    print("###############")
                    print(bp)
                else:
                    if region == '001':
                        continue
                    arr.append(mapping[region])
                    doc['region'] = mapping[region]
                    doc['numbers'] = nums
                    try:
                        coll.insert(doc)  # and insert
                        count_ins += 1
                    except pymongo.errors.DuplicateKeyError:  # Except if it's already there
                        count_dup += 1
            count_arr[3] += 1
            continue

        if len(a)>0:
            nums = ''
            for elem in a:
                nums += elem + ','
            count += 1 
            count_arr[4] += 1
            doc['region'] = -1
            doc['numbers'] = nums
            try:
                coll.insert(doc)  # and insert
                count_ins += 1
            except pymongo.errors.DuplicateKeyError:  # Except if it's already there
                count_dup += 1
            continue
        if len(b)>0:
            nums = ''
            for elem in b:
                nums += elem + ','
            count += 1
            count_arr[5] += 1
            doc['region'] = -1
            doc['numbers'] = nums
            try:
                coll.insert(doc)  # and insert
                count_ins += 1
            except pymongo.errors.DuplicateKeyError:  # Except if it's already there
                count_dup += 1
            continue
        if len(c)>0:
            nums = ''
            for elem in c:
                nums += elem + ','
            count +=1
            count_arr[6] += 1
            doc['region'] = -1
            doc['numbers'] = nums
            try:
                coll.insert(doc)  # and insert
                count_ins += 1
            except pymongo.errors.DuplicateKeyError:  # Except if it's already there
                count_dup += 1
            continue
        if len(d)>0:
            nums = ''
            for elem in d:
                nums += elem + ','
            count += 1
            count_arr[7] += 1
            doc['region'] = -1
            doc['numbers'] = nums
            try:
                coll.insert(doc)  # and insert
                count_ins += 1
            except pymongo.errors.DuplicateKeyError:  # Except if it's already there
                count_dup += 1
            continue

    # print(count2)
    print (count)
    print(countp)
    print(f"Inserted {count_ins}, Duplicates discarded: {count_dup}")
# Out:
# 500000
# $$$$$$ +0124 4017895$$$$$
# /home/kali/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:184: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# /home/kali/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:80: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# /home/kali/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:212: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# /home/kali/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:109: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# /home/kali/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:198: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# $$$$$$ +0111 540 1613$$$$$
# $$$$$$ +852
# 94528035
# 9767$$$$$
# Be 100% sure you will have the best trip in morocco with us
#
# Contact us :
# ➖➖➖➖➖✔✔✔✔✔➖➖➖➖➖
# @moroccotourvaca
# 🌐https://t.co/Xs3dA0eGi4
#
# 📩 moroccovacationtour@gmail.com
# 📱+212 650 888… https://t.co/E7tz8EfDiV
# ###############
# ['+212 650 888']
# $$$$$$ +02026952218$$$$$
# $$$$$$ +852
# 94528035
# 9767$$$$$
# Don’t get left behind. The deadline to migrate to ISO 44001 is March 2019. If you’re not sure what to do – get in touch and call us on +44 345 080 900 and we’ll be happy to support your needs. https://t.co/Rjsww1xAzP
# ###############
# ['+44 345 080 900']
# If Your Junior Sister Likes Clubbing And Can’t Stay At Home. Just Contact Us On +39357500 We’ll Only Impregnate Her For Her To Sit At Home😂😂
# ###############
# ['+39357500']
# 13150
# 898
# Inserted 11691, Duplicates discarded: 2481
# 500000
# @sergey_alakov Sorry I meant the fact that it shows up as +1 000-000-000. I've always seen (000) 000-000 like on your screenshot
# ###############
# ['+1 000-000-000']
# $$$$$$ +923226665459
# 032266$$$$$
# $$$$$$ +923226665459
# 032266$$$$$
# /home/kali/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:139: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# $$$$$$ +01732 370347$$$$$
# Happy Tuesday everyone!
#
# 📞Call 📞
#
# +44 800 808-LIAM (UK)
# +1 (850) 888-LIAM (ROW)
#
# And listen to a snippet of #HomeWithYou from @LiamPayne highly anticipated EP #LPFirstTime out this Friday 24.8.18
# ###############
# ['+44 800 808']
# Apple is one of the famous firms propelling exceptional outlined gadgets with inventive highlights. Individuals nowadays get a kick out of the chance to utilize the gadgets with smooth plans with astonishing presentation and in addition straightforward UI. Apple gadgets have uniqueness with top of the line security that settles on them the primary decision of the people.Apple is a multinational Company having home office in California, outlines both the equipment and programming items. Best of all, Apple is the main firm in both these segments. A portion of the famous results of Apple are iPhone, iPad, and Mac. In every one of its gadgets Apple utilizes its own composed working framework that does not fit with any device other than the Apple. iOS working framework utilized as a part of Apple iPhones while Mac OS X working framework is utilized as a part of Apple Mac gadgets. The product suits of Apple that are available in the market just help its own particular gadgets. An Apple client must realize that every one of its highlights is distinctive simply like the items outlines. One of the notable highlights in Apple items is its top of the line security that is available in all the Apple gadgets.  Apple - Laptop and - Desktop - Support  2018?Being one of the well known firms bargaining with quality isn’t the standard of Apple. Every one of the Apple items that are available in the market is bought by its image name, the smoothness, outlines and security norms. Apple draws in the clients towards it with these highlights just, because of which their devices are in higher request than the other gadget in the market. Apple contraptions are created for every one of the ages’ whether a child, youngster, grown-up, home client or specialist. Where, each other firm is working for their mass corporate area, Apple for the most part center is around their gadgets and administrations. Despite the fact that Apple is estimated as one of the main organization in the market, still one ought not overlook that it plans specialized gadget that may encounter issues. Apple guarantees to settle any specialized issue with the gadget, yet in the event that the guarantee of your gadget is over then you can take PCTECH24 Apple Technical Support. On the off chance that the client faces any specialized issue, they can essentially dial the Apple Phone Number+1-877~370-8184* to get the dependable online Apple Mac Technical Support from our solid firm. Apple helpline bolster the clients to settle any inconvenience be it repairs, introduce, initiation or some other. Dial our online Apple Technical Support Phone Number +1-877~370-8184* if hunting down arrangements with Apple items and any specialized help required. Our Apple Customer Technical Support online group is available 24*7, and rendering the best ever mind administrations. In the event that the client has to know any data for the Apple gadget, they can get in touch with us by means of our online telephone number help +1-877~370-8184*. Aside from telephone bolster 1800832424 our online client specialized help group is available on Apple Chat Care Support. Thus, select the fitting way and reach to us by means of our telephone or visit bolster. Inconveniences settled on Apple Technical Support Phone Number Mac Customer Technical Support online administrations are given for a few gadgets, for example, Mac OS X, iPhone, iPad, or other related programming items. The Apple Customer Support online group we have contracted determine the genuine inconvenience to have the gadget and considerations to determine the inconvenience at all conceivable time. By going to on our site page that is the clients can take our online specialised help by means of live talk, telephone, email support and others. Our online Apple Customer Technical Support group help with number of issues which are as per the following: Application store not opening. Repairs and physical harm. iPhone Siri issues. Contact screen issue. iPhone Safa ...
# ###############
# ['+1877-370', '+1877-370', '+1877-370-8184']
# Apple is one of the famous firms propelling exceptional outlined gadgets with inventive highlights. Individuals nowadays get a kick out of the chance to utilize the gadgets with smooth plans with astonishing presentation and in addition straightforward UI. Apple gadgets have uniqueness with top of the line security that settles on them the primary decision of the people.Apple is a multinational Company having home office in California, outlines both the equipment and programming items. Best of all, Apple is the main firm in both these segments. A portion of the famous results of Apple are iPhone, iPad, and Mac. In every one of its gadgets Apple utilizes its own composed working framework that does not fit with any device other than the Apple. iOS working framework utilized as a part of Apple iPhones while Mac OS X working framework is utilized as a part of Apple Mac gadgets. The product suits of Apple that are available in the market just help its own particular gadgets. An Apple client must realize that every one of its highlights is distinctive simply like the items outlines. One of the notable highlights in Apple items is its top of the line security that is available in all the Apple gadgets.  Apple - Laptop and - Desktop - Support  2018?Being one of the well known firms bargaining with quality isn’t the standard of Apple. Every one of the Apple items that are available in the market is bought by its image name, the smoothness, outlines and security norms. Apple draws in the clients towards it with these highlights just, because of which their devices are in higher request than the other gadget in the market. Apple contraptions are created for every one of the ages’ whether a child, youngster, grown-up, home client or specialist. Where, each other firm is working for their mass corporate area, Apple for the most part center is around their gadgets and administrations. Despite the fact that Apple is estimated as one of the main organization in the market, still one ought not overlook that it plans specialized gadget that may encounter issues. Apple guarantees to settle any specialized issue with the gadget, yet in the event that the guarantee of your gadget is over then you can take PCTECH24 Apple Technical Support. On the off chance that the client faces any specialized issue, they can essentially dial the Apple Phone Number+1-877~370-8184* to get the dependable online Apple Mac Technical Support from our solid firm. Ap
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/tFxl7NxXwj
# ###############
# ['+17 2145 -102', '+16 2187 -953', '+15 2248 -578', '+14 2312 -100', '+13 2358 -61']
# BMD is higher
# Oct 0
# Nov +17 2145 -102 lots
# Dec +16 2187 -953 lots
# Jan +15 2248 -578 lots
# Feb +14 2312 -100 lots
# Mar +13 2358 -61 lots
# Vol 2191 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/tFxl7NxXwj
# ###############
# ['+17 2145 -102', '+16 2187 -953', '+15 2248 -578', '+14 2312 -100', '+13 2358 -61']
# BMD is higher
# Oct 0
# Nov +17 2145 -102 lots
# Dec +16 2187 -953 lots
# Jan +15 2248 -578 lots
# Feb +14 2312 -100 lots
# Mar +13 2358 -61 lots
# Vol 2191 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/tFxl7NxXwj
# ###############
# ['+17 2145 -102', '+16 2187 -953', '+15 2248 -578', '+14 2312 -100', '+13 2358 -61']
# Looking for a serious and honest baby to spoil and care for ..$800weekly allowance ..please RT before DM on whatsapp (+177143297741) for me to notice you
#  #sugardaddy  #Sugarbaby #Sugarbabywanted #sugardaddywanted #sugardaddyneeded #sugarbabyneeded #Paypal
# ###############
# ['+177143297741']
# $$$$$$ +(857) 294-6407$$$$$
# #NEPAL: Helpline for trafficked women + children call toll free: +16600199999 https://t.co/iZ2GBRaqTs @MaitiNepal
# ###############
# ['+16600199999']
# #NEPAL: Helpline for trafficked women + children call toll free: +16600199999 https://t.co/iZ2GBRaqTs @MaitiNepal
# ###############
# ['+16600199999']
# All businesses should be forwarded to my new Whatsapp number I’m having issues with the old one
# +1 910 44144** please ask for the last 2digit via inbox
# Business only. 🙏
# ###############
# ['+1 910 44144']
# $$$$$$ +8019990037$$$$$
# 11689
# 1180
# Inserted 12858, Duplicates discarded: 203
# 500000
# BMD is higher
# Oct +16 2112 -30 lots
# Nov +17 2145 -1403 lots
# Dec +22 2193 -9804 lots
# Jan +19 2252 -5358 lots
# Feb +15 2313 -2036 lots
# Vol 21933 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/UkBofO2Kdf
# ###############
# ['+16 2112 -30', '+17 2145 -1403', '+22 2193 -9804', '+19 2252 -5358', '+15 2313 -2036']
# BMD is higher
# Oct +16 2112 -30 lots
# Nov +17 2145 -1403 lots
# Dec +22 2193 -9804 lots
# Jan +19 2252 -5358 lots
# Feb +15 2313 -2036 lots
# Vol 21933 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/UkBofO2Kdf
# ###############
# ['+16 2112 -30', '+17 2145 -1403', '+22 2193 -9804', '+19 2252 -5358', '+15 2313 -2036']
# BMD is higher
# Oct +16 2112 -30 lots
# Nov +17 2145 -1403 lots
# Dec +22 2193 -9804 lots
# Jan +19 2252 -5358 lots
# Feb +15 2313 -2036 lots
# Vol 21933 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/UkBofO2Kdf
# ###############
# ['+16 2112 -30', '+17 2145 -1403', '+22 2193 -9804', '+19 2252 -5358', '+15 2313 -2036']
# BMD is higher
# Oct +7 2103 -3 lots
# Nov +18 2146 -1216 lots
# Dec +23 2194 -8646 lots
# Jan +18 2251 -5146 lots
# Feb +16 2314 -1823 lots
# Vol 19,537 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/Va6zxCYDS7
# ###############
# ['+18 2146 -1216', '+23 2194 -8646', '+18 2251 -5146', '+16 2314 -1823']
# BMD is higher
# Oct +7 2103 -3 lots
# Nov +18 2146 -1216 lots
# Dec +23 2194 -8646 lots
# Jan +18 2251 -5146 lots
# Feb +16 2314 -1823 lots
# Vol 19,537 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/Va6zxCYDS7
# ###############
# ['+18 2146 -1216', '+23 2194 -8646', '+18 2251 -5146', '+16 2314 -1823']
# BMD is higher
# Oct +7 2103 -3 lots
# Nov +18 2146 -1216 lots
# Dec +23 2194 -8646 lots
# Jan +18 2251 -5146 lots
# Feb +16 2314 -1823 lots
# Vol 19,537 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/Va6zxCYDS7
# ###############
# ['+18 2146 -1216', '+23 2194 -8646', '+18 2251 -5146', '+16 2314 -1823']
# BMD is higher
# Oct +7 2103 -3 lots
# Nov +15 2143 -1027 lots
# Dec +19 2190 -7744 lots
# Jan +14 2247 -4650 lots
# Feb +11 2309 -1697 lots
# Vol 17,127 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/9eb8ko8J28
# ###############
# ['+15 2143 -1027', '+19 2190 -7744', '+14 2247 -4650', '+11 2309 -1697']
# BMD is higher
# Oct +7 2103 -3 lots
# Nov +15 2143 -1027 lots
# Dec +19 2190 -7744 lots
# Jan +14 2247 -4650 lots
# Feb +11 2309 -1697 lots
# Vol 17,127 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/9eb8ko8J28
# ###############
# ['+15 2143 -1027', '+19 2190 -7744', '+14 2247 -4650', '+11 2309 -1697']
# BMD is higher
# Oct +7 2103 -3 lots
# Nov +15 2143 -1027 lots
# Dec +19 2190 -7744 lots
# Jan +14 2247 -4650 lots
# Feb +11 2309 -1697 lots
# Vol 17,127 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/9eb8ko8J28
# ###############
# ['+15 2143 -1027', '+19 2190 -7744', '+14 2247 -4650', '+11 2309 -1697']
# BMD is higher
# Oct +7 2103 -3 lots
# Nov +15 2143 -1027 lots
# Dec +19 2190 -7744 lots
# Jan +14 2247 -4650 lots
# Feb +11 2309 -1697 lots
# Vol 17,127 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/9eb8ko8J28
# ###############
# ['+15 2143 -1027', '+19 2190 -7744', '+14 2247 -4650', '+11 2309 -1697']
# BMD is steady
# Oct +7 2103 -3 lots
# Nov +7 2135 -524 lots
# Dec +13 2184 -4863 lots
# Jan +12 2245 -2432 lots
# Feb +12 2310 -874 lots
# Vol 10,111 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/ASfalFPIDt
# ###############
# ['+7 2135 -524', '+13 2184 -4863', '+12 2245 -2432', '+12 2310 -874']
# BMD is steady
# Oct +7 2103 -3 lots
# Nov +7 2135 -524 lots
# Dec +13 2184 -4863 lots
# Jan +12 2245 -2432 lots
# Feb +12 2310 -874 lots
# Vol 10,111 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/ASfalFPIDt
# ###############
# ['+7 2135 -524', '+13 2184 -4863', '+12 2245 -2432', '+12 2310 -874']
# BMD is steady
# Oct +7 2103 -3 lots
# Nov +7 2135 -524 lots
# Dec +13 2184 -4863 lots
# Jan +12 2245 -2432 lots
# Feb +12 2310 -874 lots
# Vol 10,111 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/ASfalFPIDt
# ###############
# ['+7 2135 -524', '+13 2184 -4863', '+12 2245 -2432', '+12 2310 -874']
# BMD is steady
# Oct +7 2103 -3 lots
# Nov +7 2135 -524 lots
# Dec +13 2184 -4863 lots
# Jan +12 2245 -2432 lots
# Feb +12 2310 -874 lots
# Vol 10,111 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/ASfalFPIDt
# ###############
# ['+7 2135 -524', '+13 2184 -4863', '+12 2245 -2432', '+12 2310 -874']
# BMD remains steady
# Oct +20 2116 -36 lots
# Nov +18 2146 -1816 lots
# Dec +23 2194 -12548 lots
# Jan +18 2251 -6219 lots
# Feb +13 2311 -2700 lots
# Vol 27058 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/Zit9bVCEvL
# ###############
# ['+20 2116 -36', '+18 2146 -1816', '+23 2194 -12548', '+18 2251 -6219', '+13 2311 -2700']
# BMD remains steady
# Oct +20 2116 -36 lots
# Nov +18 2146 -1816 lots
#
# Contact:
# @GodsonOsawe
#
# Phone numbers:
# +1 - 920 - 360 - 8252.
#
# Visit website:
# https://t.co/EJdYhW2A49
#
# Early Bird Gets The… https://t.co/b3rgqbehaU
# ###############
# ['+1 - 920 - 360']
# #NEPAL: Helpline for trafficked women + children call toll free: +16600199999 https://t.co/iZ2GBRaqTs @MaitiNepal
# ###############
# ['+16600199999']
# #NEPAL: Helpline for trafficked women + children call toll free: +16600199999 https://t.co/iZ2GBRaqTs @MaitiNepal
# ###############
# ['+16600199999']
# 10078
# 768
# Inserted 10843, Duplicates discarded: 103
# 500000
# I liked a @YouTube video https://t.co/hwZSI0Y9M3 Painting contractors at a fair price in Montebello----call now +1 818-848-48675
# ###############
# ['+1 818-848-48675']
# $$$$$$ +965 66929612
#
# 6707$$$$$
# @karenkaren118 @WynneGuglielmo @TamilToes @PeterEgan6 @PeterAskin1 @rickygervais @SOSmoggies @tws_pk @Rubiconski @reddogsusie @bvanhool @CathyGarside @convsys @GirvinElaine @dodo 🙏🏼 Pls join us in our fight to save them. Save INNOCENT TIGRESS &amp; her 2 cubs frm getting shot on govt’s orders, who been falsely accused of being a man eater &amp; they have no proof. PLS CALL ON +1 8080740440 FRM ANYWHERE IN THE WORLD. Call ll disconnect by itself #LetAvniLive
# ###############
# ['+1 8080740440']
# @karenkaren118 @WynneGuglielmo @TamilToes @PeterEgan6 @PeterAskin1 @rickygervais @SOSmoggies @tws_pk @Rubiconski @reddogsusie @bvanhool @CathyGarside @convsys @GirvinElaine @dodo 🙏🏼 Pls join us in our fight to save them. Save INNOCENT TIGRESS &amp; her 2 cubs frm getting shot on govt’s orders, who been falsely accused of being a man eater &amp; they have no proof. PLS CALL ON +1 8080740440 FRM ANYWHERE IN THE WORLD. Call ll disconnect by itself #LetAvniLive
# ###############
# ['+1 8080740440']
# @karenkaren118 @WynneGuglielmo @TamilToes @PeterEgan6 @PeterAskin1 @rickygervais @SOSmoggies @tws_pk @Rubiconski @reddogsusie @bvanhool @CathyGarside @convsys @GirvinElaine @dodo 🙏🏼 Pls join us in our fight to save them. Save INNOCENT TIGRESS &amp; her 2 cubs frm getting shot on govt’s orders, who been falsely accused of being a man eater &amp; they have no proof. PLS CALL ON +1 8080740440 FRM ANYWHERE IN THE WORLD. Call ll disconnect by itself #LetAvniLive
# ###############
# ['+1 8080740440']
# @karenkaren118 @WynneGuglielmo @TamilToes @PeterEgan6 @PeterAskin1 @rickygervais @SOSmoggies @tws_pk @Rubiconski @reddogsusie @bvanhool @CathyGarside @convsys @GirvinElaine @dodo 🙏🏼 Pls join us in our fight to save them. Save INNOCENT TIGRESS &amp; her 2 cubs frm getting shot on govt’s orders, who been falsely accused of being a man eater &amp; they have no proof. PLS CALL ON +1 8080740440 FRM ANYWHERE IN THE WORLD. Call ll disconnect by itself #LetAvniLive
# ###############
# ['+1 8080740440']
# $$$$$$ +008618171222707$$$$$
# 10620
# 951
# Inserted 11564, Duplicates discarded: 138
# 188395
# $$$$$$ +08101764079$$$$$
# $$$$$$ +00818037051979$$$$$
# 3552
# 352
# Inserted 3902, Duplicates discarded: 33
# 0
# 0
# 0
# Inserted 0, Duplicates discarded: 0
# 0
# 0
# 0
# Inserted 0, Duplicates discarded: 0
# 0
# 0
# 0
# Inserted 0, Duplicates discarded: 0
# 0
# 0
# 0
# Inserted 0, Duplicates discarded: 0
# 0
# 0
# 0
# Inserted 0, Duplicates discarded: 0
# 0
# 0
# 0
# Inserted 0, Duplicates discarded: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-96219c311972> in <module>()
#       8     coll = db_new.new_posts
#       9
# ---> 10     for doc in curs:
#      11         list_to_be_fill_with_documents.append(doc)
#      12
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in next(self)
#    1187         if self.__empty:
#    1188             raise StopIteration
# -> 1189         if len(self.__data) or self._refresh():
#    1190             if self.__manipulate:
#    1191                 _db = self.__collection.database
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in _refresh(self)
#    1102                                   self.__session,
#    1103                                   self.__collection.database.client)
# -> 1104             self.__send_message(q)
#    1105         elif self.__id:  # Get More
#    1106             if self.__limit:
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in __send_message(self, operation)
#     929             try:
#     930                 response = client._send_message_with_response(
# --> 931                     operation, exhaust=self.__exhaust, address=self.__address)
#     932                 self.__address = response.address
#     933                 if self.__exhaust:
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/mongo_client.py in _send_message_with_response(self, operation, exhaust, address)
#    1143             self.__all_credentials,
#    1144             self._event_listeners,
# -> 1145             exhaust)
#    1146
#    1147     def _reset_on_error(self, server, func, *args, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/mongo_client.py in _reset_on_error(self, server, func, *args, **kwargs)
#    1154         """
#    1155         try:
# -> 1156             return func(*args, **kwargs)
#    1157         except NetworkTimeout:
#    1158             # The socket has been closed. Don't reset the server.
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/server.py in send_message_with_response(self, operation, set_slave_okay, all_credentials, listeners, exhaust)
#     104             try:
#     105                 sock_info.send_message(data, max_doc_size)
# --> 106                 reply = sock_info.receive_message(request_id)
#     107             except Exception as exc:
#     108                 if publish:
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in receive_message(self, request_id)
#     610                                    self.max_message_size)
#     611         except BaseException as error:
# --> 612             self._raise_connection_failure(error)
#     613
#     614     def _raise_if_not_writable(self, unacknowledged):
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in _raise_connection_failure(self, error)
#     743             _raise_connection_failure(self.address, error)
#     744         else:
# --> 745             raise error
#     746
#     747     def __eq__(self, other):
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in receive_message(self, request_id)
#     608         try:
#     609             return receive_message(self.sock, request_id,
# --> 610                                    self.max_message_size)
#     611         except BaseException as error:
#     612             self._raise_connection_failure(error)
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/network.py in receive_message(sock, request_id, max_message_size)
#     171     # Ignore the response's request id.
#     172     length, _, response_to, op_code = _UNPACK_HEADER(
# --> 173         _receive_data_on_socket(sock, 16))
#     174     # No request_id for exhaust cursor "getMore".
#     175     if request_id is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/network.py in _receive_data_on_socket(sock, length)
#     230         while bytes_read < length:
#     231             try:
# --> 232                 chunk_length = sock.recv_into(mv[bytes_read:])
#     233             except (IOError, OSError) as exc:
#     234                 if _errno_from_exception(exc) == errno.EINTR:
#
# KeyboardInterrupt:

# %%
2
# Out:
# 2
