# %%
import numpy as np
import re

# %%
import pymongo
import pycountry
import phonenumbers
from phonenumbers.phonenumberutil import region_code_for_country_code
from phonenumbers.phonenumberutil import region_code_for_number

### -h ds241121.mlab.com:41121 -d social_data -c posts -u user -p pass1234 --file test.json

# connection_params = {
#     'user': 'user',
#     'password': 'password',
#     'host': 'localhost',
#     'port': 27017,
#     'namespace': 'social_data',
# }

# connection = pymongo.MongoClient(
#     'mongodb://{user}:{password}@{host}:'
#     '{port}/{namespace}'.format(**connection_params)
# )

# db = connection.social_data
client = pymongo.MongoClient('mongodb://user:password@localhost:27017/')
db = getattr(client, '10M_social_data')
coll = db.posts
print(db.list_collection_names())
# Out:
# ['posts']

# %%
mapping = {country.alpha_2: country.name for country in pycountry.countries}

# %%
for i in range(6):
    list_to_be_fill_with_documents=[]

    curs=db.posts.find().limit(2000000).skip(2000000*i)
    
    client = pymongo.MongoClient('mongodb://user:password@localhost:27017/')
    db_new = client.filtered_posts
    coll = db_new.new_posts

    for doc in curs:
        list_to_be_fill_with_documents.append(doc)
    
    print(len(list_to_be_fill_with_documents))
    
    ####################################################33
    
    np_arr = np.asarray(list_to_be_fill_with_documents)
    
    arr = []
    count_ins = 0
    count_dup = 0
    r1 = r'(\d{1,5}-\d{3,5}-\d{3,7})' 
    r1p = r'(\+\d{1,5}-\d{3,5}-\d{3,7})' 

    r2 = r'\(?[\d]{3}\)?[-\s]?[\d]{3}[-\s]?[\d]{3,6}'
    r2p = r'\+\(?[\d]{3}\)?[-\s]?[\d]{3}[-\s]?[\d]{3,6}'
    r = r'(\d[\d\s-]{5,13}\d{2,4})'

    rp = r'(\+\d[\d\s-]{5,13}\d{2,4})'
    r3 = r'(\(\d{3,5}\)[-\s\d]\d{2,5}[-\s\d]\d{2,6})'  
    r3p = r'(\+\(\d{3,5}\)[-\s\d]\d{2,5}[-\s\d]\d{2,6})'  

    # r2 = r'(1\s?)?((\([0-9]{3}\))|[0-9]{3})[\s\-]?[\0-9]{3}[\s\-]?[0-9]{4}'
    #d dddddd, dddddddd,d        
    # r2= r'\$ *\d+[\.]*\d+|\d+[\.]*\d+\$'
    # r3= r'^\d+\s|\s\d+\s|\s\d+$'
    count = 0
    countp = 0
    count_arr = [0]*8
    for i,doc in enumerate(np_arr):
        content = doc['content']
        a = re.findall(r2, content)
        b = re.findall(r1, content)
        c = re.findall(r, content)
        d = re.findall(r3,content)
        ap = re.findall(r2p, content)
        bp = re.findall(r1p, content)
        cp = re.findall(rp, content)
        dp = re.findall(r3p,content)
        # e = re.findall(r'(\d[\d ]{5,13}\d{2})', content)

    #     if len(e) > 0:
    #         count2 += 1
    #         # print(e)

        if len(ap)>0:
            countp += 1
            nums = ''
            for elem in ap:
                try:
                    region = region_code_for_number(phonenumbers.parse(elem))
                except:
                    print(region)
                    continue
                count_arr[0] += 1

                nums += elem + ','
                if region is None:
                    print(doc['content'])
                    print("###############")
                    print(ap)
                else:
                    arr.append(mapping[region])
                    doc['region'] = mapping[region]
                    doc['numbers'] = nums

                    try:
                        coll.insert(doc)  # and insert
                        count_ins += 1
                    except pymongo.errors.DuplicateKeyError:  # Except if it's already there
                        count_dup += 1
            continue



        if len(cp)>0:
            countp += 1
            nums = ''
            for elem in cp:
                try:
                    region = region_code_for_number(phonenumbers.parse(elem))
                except:
                    print(region)
                    continue
                nums += elem + ','
                if region is None:
                    print(doc['content'])
                    print("###############")
                    print(cp)
                else:
                    arr.append(mapping[region])
                    doc['region'] = mapping[region]
                    doc['numbers'] = nums
                    try:
                        coll.insert(doc)  # and insert
                        count_ins += 1
                    except pymongo.errors.DuplicateKeyError:  # Except if it's already there
                        count_dup += 1
            count_arr[1] += 1

            continue

        if len(dp)>0:
            countp += 1
            nums = ''
            for elem in dp:
                try:
                    region = region_code_for_number(phonenumbers.parse(elem))
                except:
                    print(region)
                    continue
                nums += elem + ','
                if region is None:
                    print(doc['content'])
                    doc['nums'] = nums
                    print("###############")
                    print(dp)
                else:
                    arr.append(mapping[region])
                    doc['region'] = mapping[region]
                    doc['numbers'] = nums
                    try:
                        coll.insert(doc)  # and insert
                        count_ins += 1
                    except pymongo.errors.DuplicateKeyError:  # Except if it's already there
                        count_dup += 1
            count_arr[2] += 1
            continue


        if len(bp)>0:
            countp += 1
            nums = ''
            for elem in bp:
                try:
                    region = region_code_for_number(phonenumbers.parse(elem))
                except:
                    print(region)
                    continue
                nums += elem + ','
                if region is None:
                    print(doc['content'])
                    print("###############")
                    print(bp)
                else:
                    arr.append(mapping[region])
                    doc['region'] = mapping[region]
                    doc['numbers'] = nums
                    try:
                        coll.insert(doc)  # and insert
                        count_ins += 1
                    except pymongo.errors.DuplicateKeyError:  # Except if it's already there
                        count_dup += 1
            count_arr[3] += 1
            continue

        if len(a)>0:
            nums = ''
            for elem in a:
                nums += elem + ','
            count += 1 
            count_arr[4] += 1
            doc['region'] = -1
            doc['numbers'] = nums
            try:
                coll.insert(doc)  # and insert
                count_ins += 1
            except pymongo.errors.DuplicateKeyError:  # Except if it's already there
                count_dup += 1
            continue
        if len(b)>0:
            nums = ''
            for elem in b:
                nums += elem + ','
            count += 1
            count_arr[5] += 1
            doc['region'] = -1
            doc['numbers'] = nums
            try:
                coll.insert(doc)  # and insert
                count_ins += 1
            except pymongo.errors.DuplicateKeyError:  # Except if it's already there
                count_dup += 1
            continue
        if len(c)>0:
            nums = ''
            for elem in c:
                nums += elem + ','
            count +=1
            count_arr[6] += 1
            doc['region'] = -1
            doc['numbers'] = nums
            try:
                coll.insert(doc)  # and insert
                count_ins += 1
            except pymongo.errors.DuplicateKeyError:  # Except if it's already there
                count_dup += 1
            continue
        if len(d)>0:
            nums = ''
            for elem in d:
                nums += elem + ','
            count += 1
            count_arr[7] += 1
            doc['region'] = -1
            doc['numbers'] = nums
            try:
                coll.insert(doc)  # and insert
                count_ins += 1
            except pymongo.errors.DuplicateKeyError:  # Except if it's already there
                count_dup += 1
            continue

    # print(count2)
    print (count)
    print(countp)
    print(f"Inserted {count_ins}, Duplicates discarded: {count_dup}")
# Out:
# 2000000
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:204: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:176: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:78: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:105: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:190: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# GB
# Penang Island City tour &amp; Transport
# 📱 +6106904300
# Whatsapp
# FB Milah Muhd https://t.co/J5Uhlq4Lq7
# ###############
# ['+6106904300']
# MY
# Contact us :
# ➖➖➖➖➖✔✔✔✔✔➖➖➖➖➖
# @moroccotourvaca
# 🌐https://t.co/Xs3dzZX4Tu
#
# 📩 moroccovacationtour@gmail.com
# 📱+212 650 888 617
# 🌍Morocco.
#
# This tour includes:
#
# 3days 2nights From Marrakech… https://t.co/39ouavEAo2
# ###############
# ['+212 650 888']
# RS
# RS
# RS
# @SabrinaAnnLynn Let’s be friends please call me 91+7358244734
# ###############
# ['+7358244734']
# NG
# CN
# CN
# SG
# AE
# [+6202-374] really, everytime Do kyungsoo comes out, it's so depressing TT. putting that aside, Do kyungsoo's acting is daebak today
# [+1959 -38] wa.. he got lou gehrig's.. is he really an idol? when i watched, i got goosebumps
#
# #괜사_한강우_4주년
# ###############
# ['+6202-374', '+1959 -38']
# [+6202-374] really, everytime Do kyungsoo comes out, it's so depressing TT. putting that aside, Do kyungsoo's acting is daebak today
# [+1959 -38] wa.. he got lou gehrig's.. is he really an idol? when i watched, i got goosebumps
#
# #괜사_한강우_4주년
# ###############
# ['+6202-374', '+1959 -38']
# [+6202-374] really, everytime Do kyungsoo comes out, it's so depressing TT. putting that aside, Do kyungsoo's acting is daebak today
# [+1959 -38] wa.. he got lou gehrig's.. is he really an idol? when i watched, i got goosebumps
#
# #괜사_한강우_4주년
# ###############
# ['+6202-374', '+1959 -38']
# [+6202-374] really, everytime Do kyungsoo comes out, it's so depressing TT. putting that aside, Do kyungsoo's acting is daebak today
# [+1959 -38] wa.. he got lou gehrig's.. is he really an idol? when i watched, i got goosebumps
#
# #괜사_한강우_4주년
# ###############
# ['+6202-374', '+1959 -38']
# #NEPAL: Helpline for trafficked women + children call toll free: +16600199999 https://t.co/iZ2GBRaqTs @MaitiNepal
# ###############
# ['+16600199999']
# #NEPAL: Helpline for trafficked women + children call toll free: +16600199999 https://t.co/iZ2GBRaqTs @MaitiNepal
# ###############
# ['+16600199999']
# [+6202-374] really, everytime Do kyungsoo comes out, it's so depressing TT. putting that aside, Do kyungsoo's acting is daebak today
# [+1959 -38] wa.. he got lou gehrig's.. is he really an idol? when i watched, i got goosebumps
#
# #괜사_한강우_4주년
# ###############
# ['+6202-374', '+1959 -38']
# [+6202-374] really, everytime Do kyungsoo comes out, it's so depressing TT. putting that aside, Do kyungsoo's acting is daebak today
# [+1959 -38] wa.. he got lou gehrig's.. is he really an idol? when i watched, i got goosebumps
#
# #괜사_한강우_4주년
# ###############
# ['+6202-374', '+1959 -38']
# [+6202-374] really, everytime Do kyungsoo comes out, it's so depressing TT. putting that aside, Do kyungsoo's acting is daebak today
# [+1959 -38] wa.. he got lou gehrig's.. is he really an idol? when i watched, i got goosebumps
#
# #괜사_한강우_4주년
# ###############
# ['+6202-374', '+1959 -38']
# [+6202-374] really, everytime Do kyungsoo comes out, it's so depressing TT. putting that aside, Do kyungsoo's acting is daebak today
# [+1959 -38] wa.. he got lou gehrig's.. is he really an idol? when i watched, i got goosebumps
#
# #괜사_한강우_4주년
# ###############
# ['+6202-374', '+1959 -38']
# BMD is steady
# Aug 0
# Sep +8 2200 -534 lots
# Oct +10 2204 -2394 lots
# Nov +13 2215 -505 lots
# Dec +8 2223 -192 lots
# Jan +7 2249 -53 lots
# Vol 4150 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/o56BYWjzgo
# ###############
# ['+8 2200 -534', '+10 2204 -2394', '+13 2215 -505', '+8 2223 -192', '+7 2249 -53']
# BMD is steady
# Aug 0
# Sep +8 2200 -534 lots
# Oct +10 2204 -2394 lots
# Nov +13 2215 -505 lots
# Dec +8 2223 -192 lots
# Jan +7 2249 -53 lots
# Vol 4150 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/o56BYWjzgo
# ###############
# ['+8 2200 -534', '+10 2204 -2394', '+13 2215 -505', '+8 2223 -192', '+7 2249 -53']
# BMD is steady
# Aug 0
# Sep +8 2200 -534 lots
# Oct +10 2204 -2394 lots
# Nov +13 2215 -505 lots
# Dec +8 2223 -192 lots
# Jan +7 2249 -53 lots
# Vol 4150 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/o56BYWjzgo
# ###############
# ['+8 2200 -534', '+10 2204 -2394', '+13 2215 -505', '+8 2223 -192', '+7 2249 -53']
# BMD is steady
# Aug 0
# Sep +7 2199 -70 lots
# Oct +7 2201 -810 lots
# Nov +7 2209 -189 lots
# Dec +7 2222 -80 lots
# Vol 1365 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/XjIjbfkurw
# ###############
# ['+7 2199 -70', '+7 2201 -810', '+7 2209 -189', '+7 2222 -80']
# BMD is steady
# Aug 0
# Sep +7 2199 -70 lots
# Oct +7 2201 -810 lots
# Nov +7 2209 -189 lots
# Dec +7 2222 -80 lots
# Vol 1365 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/XjIjbfkurw
# ###############
# ['+7 2199 -70', '+7 2201 -810', '+7 2209 -189', '+7 2222 -80']
# BMD is steady
# Aug 0
# Sep +7 2199 -70 lots
# Oct +7 2201 -810 lots
# Nov +7 2209 -189 lots
# Dec +7 2222 -80 lots
# Vol 1365 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/XjIjbfkurw
# ###############
# ['+7 2199 -70', '+7 2201 -810', '+7 2209 -189', '+7 2222 -80']
# BMD is steady
# Aug 0
# Sep +7 2199 -70 lots
# Oct +7 2201 -810 lots
# Nov +7 2209 -189 lots
# Dec +7 2222 -80 lots
# Vol 1365 lots
# Get a free trial of Palm Oil Analytics newsletter: info@palmoilanalytics.com
# Visit https://t.co/yLNQEmpVln for more prices https://t.co/XjIjbfkurw
# ###############
# ['+7 2199 -70', '+7 2201 -810', '+7 2209 -189', '+7 2222 -80']
# [+6202-374] really, everytime Do kyungsoo comes out, it's so depressing TT. putting that aside, Do kyungsoo's acting is daebak today
# [+1959 -38] wa.. he got lou gehrig's.. is he really an idol? when i watched, i got goosebumps
#
# #괜사_한강우_4주년
# ###############
# ['+6202-374', '+1959 -38']
# MY
# IN
# TR
# More Info: https://t.co/IbKWgFwXqE #EuroScicon #OccupationalHealth2019Congress focusing for another #Successfulevent at #Berlin on April 18-19, 2019...extending a warm #Welcome for participation at Congress...some glimpses of our #success...WhatsApp us: +44238214671 https://t.co/YOBOE2356o
# ###############
# ['+44238214671']
# IN
# CN
# [+6202-374] really, everytime Do kyungsoo comes out, it's so depressing TT. putting that aside, Do kyungsoo's acting is daebak today
# [+1959 -38] wa.. he got lou gehrig's.. is he really an idol? when i watched, i got goosebumps
#
# #괜사_한강우_4주년
# ###############
# ['+6202-374', '+1959 -38']
# Call us now for any meeting or support on programming or related worry at Magellan Toll Free Number +1-844-708... https://t.co/Njwrg9sZ26
# ###############
# ['+1-844-708']
# Magellan GPS Support is a best Phone Number and talk support for Magellan gadget clients in USA +1-844-307-570... https://t.co/LPJ3t9Q7Go
# ###############
# ['+1-844-307-570']
# ANTIVIRUS SUPPORT: Quicken customer support phone number +1-888-455-5... https://t.co/vIsS7pMDPP #quickensupport #quickenhelplinenuber #quickenantivirus......
# ###############
# ['+1-888-455']
# 36172
# 2993
# Inserted 26615, Duplicates discarded: 12916
# ---------------------------------------------------------------------------
# CursorNotFound                            Traceback (most recent call last)
# <ipython-input-5-fcbada3b4048> in <module>()
#       8     coll = db_new.new_posts
#       9
# ---> 10     for doc in curs:
#      11         list_to_be_fill_with_documents.append(doc)
#      12
#
# /home/kali/.local/lib/python3.6/site-packages/pymongo/cursor.py in next(self)
#    1187         if self.__empty:
#    1188             raise StopIteration
# -> 1189         if len(self.__data) or self._refresh():
#    1190             if self.__manipulate:
#    1191                 _db = self.__collection.database
#
# /home/kali/.local/lib/python3.6/site-packages/pymongo/cursor.py in _refresh(self)
#    1124                                         self.__collection.database.client,
#    1125                                         self.__max_await_time_ms)
# -> 1126                 self.__send_message(g)
#    1127
#    1128         return len(self.__data)
#
# /home/kali/.local/lib/python3.6/site-packages/pymongo/cursor.py in __send_message(self, operation)
#     980                 first = docs[0]
#     981                 client._receive_cluster_time(first, self.__session)
# --> 982                 helpers._check_command_response(first)
#     983         except OperationFailure as exc:
#     984             self.__killed = True
#
# /home/kali/.local/lib/python3.6/site-packages/pymongo/helpers.py in _check_command_response(response, msg, allowable_errors, parse_write_concern_error)
#     150                 raise ExecutionTimeout(errmsg, code, response)
#     151             elif code == 43:
# --> 152                 raise CursorNotFound(errmsg, code, response)
#     153
#     154             msg = msg or "%s"
#
# CursorNotFound: cursor id 11997182470 not found
