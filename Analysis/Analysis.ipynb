# %% [markdown]
# # Analysis List
#
# 1. No. of posts per category    with percentage
# 2. Country generating most spam
# 3. Top 10 spammers, their categories, number of posts
# 4. Check how many users suspended
# 5. Total number of users that generated this much spam.
# 6. Top hashtags in the dataset
# 7. Major Country for each category
# 8. Same phone number generating multiple campaigns.
# 9. Maximum number of people related to same campaign - same phone number - different ID
# 10. Cross Platform posts.

# %% [markdown]
# # 1. No. of posts per category with percentage

# %%
import pymongo

client = pymongo.MongoClient()
db = getattr(client, 'clustered_data')
print(db.list_collection_names())
# Out:
# ['posts']

# %%
posts = db.posts
curs = posts.find()

# %%
count_dict = {}

# %%
dicttt = {"abc": 123}

if "abc" in dicttt:
    print("YES")
# Out:
# YES

# %%
for post in curs:
#     print(post)
    if post['category'] not in count_dict:
        count_dict[post['category']] = 1
    else:
        count_dict[post['category']] += 1

# %%
import operator

sorted(count_dict.items(), key=operator.itemgetter(1), reverse=True)

# %% [markdown]
# # 2. Country generating most spam (in percent)

# %%
client = pymongo.MongoClient()
db = getattr(client, 'clustered_data')
print(db.list_collection_names())
posts = db.posts
curs = posts.find()

country_spam = {}
# Out:
# ['posts']

# %%
import sys

for i, post in enumerate(curs):
#     print(post)
    
#     if type(post['location']) == list:
# #         print(post['location'])
#         lon = post['location'][0]
#         lat = post['location'][1]
# #         print(rg.search((lon, lat)))
#         post['location'] = mapping[rg.search((lon, lat))[0]['cc']]
        
    
#     if post['region'] == -1 and post['location'] != -1 and post['location'] not in count_dict:
# #         print(post)
# #         print (post['location'])
#         country_spam[post['location']] = 1
        
#     elif post['region'] == -1 and post['location'] != -1:
#         country_spam[post['location']] += 1
            
    if post['region'] not in country_spam and post['region'] != -1:
        country_spam[post['region']] = 1
    elif post['region'] != -1:
        country_spam[post['region']] += 1
        


#     sys.stdout.write("\r%i" % i)
#     sys.stdout.flush()

# %%
summ = 0

for k, v in country_spam.items():
    summ += v
print(summ)
# Out:
# 33737

# %%
import operator

sorted(country_spam.items(), key=operator.itemgetter(1), reverse=True)
# Out:
# [('India', 8801),
#  ('Nigeria', 4072),
#  ('United States', 2476),
#  ('Philippines', 1969),
#  ('China', 1807),
#  ('United Arab Emirates', 1728),
#  ('Kenya', 1280),
#  ('Pakistan', 1088),
#  ('Malaysia', 1012),
#  ('South Africa', 970),
#  ('United Kingdom', 894),
#  ('Uganda', 752),
#  ('Indonesia', 677),
#  ('Ghana', 547),
#  ('Zimbabwe', 516),
#  ('Germany', 279),
#  ('Viet Nam', 262),
#  ('Iraq', 232),
#  ('Turkey', 229),
#  ('Zambia', 222),
#  ('Tanzania, United Republic of', 215),
#  ('Hong Kong', 171),
#  ('Singapore', 169),
#  ('Italy', 156),
#  ('Australia', 153),
#  ('Thailand', 134),
#  ('Spain', 131),
#  ('Qatar', 131),
#  ('Egypt', 121),
#  ('Bahrain', 116),
#  ('Rwanda', 113),
#  ('Saudi Arabia', 100),
#  ('Bangladesh', 99),
#  ('Korea, Republic of', 98),
#  ('Netherlands', 93),
#  ('Maldives', 85),
#  ('Kuwait', 81),
#  ('Namibia', 77),
#  ('Ireland', 75),
#  ('Serbia', 71),
#  ('Argentina', 70),
#  ('Canada', 69),
#  ('Cambodia', 66),
#  ('Botswana', 66),
#  ('Sri Lanka', 62),
#  ('Oman', 56),
#  ('Belgium', 53),
#  ('Nepal', 52),
#  ('Cameroon', 52),
#  ('Venezuela, Bolivarian Republic of', 52),
#  ('France', 49),
#  ('Japan', 49),
#  ('Lebanon', 49),
#  ('Malawi', 42),
#  ('Chile', 35),
#  ('Portugal', 34),
#  ('Mexico', 27),
#  ('Bosnia and Herzegovina', 27),
#  ('Ukraine', 26),
#  ('Russian Federation', 23),
#  ('Israel', 20),
#  ('Romania', 19),
#  ('New Zealand', 19),
#  ('Peru', 18),
#  ('Jordan', 17),
#  ('Sudan', 17),
#  ('Colombia', 16),
#  ('Brazil', 15),
#  ('Iran, Islamic Republic of', 15),
#  ('Haiti', 14),
#  ('Cyprus', 14),
#  ('Costa Rica', 13),
#  ('Gambia', 13),
#  ('Aruba', 13),
#  ('Switzerland', 12),
#  ('Grenada', 12),
#  ('Morocco', 11),
#  ('Georgia', 11),
#  ('Tajikistan', 11),
#  ('Sweden', 10),
#  ('Jersey', 10),
#  ('Poland', 10),
#  ('Malta', 9),
#  ('Sint Maarten (Dutch part)', 9),
#  ('Sierra Leone', 9),
#  ('Mozambique', 8),
#  ('Azerbaijan', 8),
#  ('Austria', 8),
#  ('Hungary', 7),
#  ('Benin', 7),
#  ('Chad', 7),
#  ('Swaziland', 7),
#  ('Greece', 6),
#  ('Yemen', 6),
#  ('Guinea-Bissau', 6),
#  ('Gibraltar', 6),
#  ('Bhutan', 6),
#  ('Czechia', 6),
#  ('Denmark', 6),
#  ('Taiwan, Province of China', 6),
#  ('Bulgaria', 6),
#  ('Senegal', 5),
#  ('Congo, The Democratic Republic of the', 5),
#  ('Liberia', 4),
#  ('Slovenia', 4),
#  ('Albania', 4),
#  ('Finland', 4),
#  ('Algeria', 4),
#  ('Somalia', 4),
#  ("Côte d'Ivoire", 4),
#  ('Brunei Darussalam', 3),
#  ('Belarus', 3),
#  ('Estonia', 3),
#  ('Lesotho', 3),
#  ('Mauritania', 3),
#  ('Myanmar', 3),
#  ('Tunisia', 3),
#  ('Armenia', 3),
#  ('Slovakia', 3),
#  ('Angola', 3),
#  ('Panama', 3),
#  ('Vanuatu', 3),
#  ('Ecuador', 3),
#  ('Guernsey', 3),
#  ('Jamaica', 3),
#  ('Ethiopia', 3),
#  ('Afghanistan', 3),
#  ('Palestine, State of', 2),
#  ('Belize', 2),
#  ('Mauritius', 2),
#  ('El Salvador', 2),
#  ('Curaçao', 2),
#  ('Barbados', 2),
#  ('Kyrgyzstan', 2),
#  ('Luxembourg', 2),
#  ('Burundi', 2),
#  ('Honduras', 2),
#  ('Mali', 2),
#  ('Norway', 2),
#  ('Bolivia, Plurinational State of', 1),
#  ('Guatemala', 1),
#  ("Lao People's Democratic Republic", 1),
#  ('Madagascar', 1),
#  ('Fiji', 1),
#  ('Nicaragua', 1),
#  ('Guinea', 1),
#  ('Virgin Islands, U.S.', 1),
#  ('Bahamas', 1),
#  ('Uruguay', 1),
#  ('Andorra', 1),
#  ('Dominican Republic', 1),
#  ('Monaco', 1),
#  ('Lithuania', 1),
#  ('Togo', 1),
#  ('Montenegro', 1),
#  ('Dominica', 1),
#  ('Latvia', 1),
#  ('Bermuda', 1),
#  ('Norfolk Island', 1)]

# %% [markdown]
# # 3. Top 10 spammers, their categories, number of posts

# %%
import pymongo
client = pymongo.MongoClient()
db = getattr(client, 'clustered_data')
print(db.list_collection_names())
posts = db.posts
curs = posts.find()
user_dict = {}
# Out:
# ['posts']

# %%
import sys


for i, post in enumerate(curs):
    if post['user_id'] not in user_dict:
        abc = set()
        abc.add(post['category'])
        user_dict[post['user_id']] = {"count": 1, "categories": abc}
    else:
        user_dict[post['user_id']]['count'] += 1
        user_dict[post['user_id']]['categories'].add(post['category'])
        
#     sys.stdout.write("\r%i" % i)
#     sys.stdout.flush()

# %% [markdown]
# # 5. Total number of users that generated this much spam.

# %%
len(user_dict)

# %% [markdown]
# # 6. Top Hashtags

# %%
import pymongo
client = pymongo.MongoClient()
db = getattr(client, 'clustered_data')
print(db.list_collection_names())
posts = db.posts
curs = posts.find()
hash_dic = {}
# Out:
# ['posts']

# %%
import sys
for i, post in enumerate(curs):
    try:
        for hashtag in post['hashtags']:
            if hashtag not in hash_dic:

                hash_dic[hashtag] = 1
            else:
                hash_dic[hashtag] += 1
    except:
        pass

# %%
hash_dic
# Out:
# {'Message': 8,
#  'music kits steam': 2,
#  'music packs free': 2,
#  'musik': 3,
#  'Pluck': 1,
#  'Sound': 3,
#  'sound effects': 2,
#  'source files meaning': 2,
#  '$$': 1,
#  '$$$': 2,
#  '5 em 5': 15,
#  'adam bianchi': 1,
#  'aloha multinivel': 15,
#  'andrew ilnyckyj': 1,
#  'buzzfeed': 1,
#  'BuzzFeedVide...': 1,
#  'cheap vs. expensive': 1,
#  'Crescer Livre': 15,
#  'doterra': 17,
#  'Food': 122,
#  'fries': 3,
#  'fry challenge': 1,
#  'I9life': 15,
#  'kimchi': 1,
#  'líder toni': 15,
#  'LOV': 1,
#  'MMn': 15,
#  'mmn 2018': 15,
#  'Montreal': 12,
#  'Multinível': 15,
#  'steven lim': 1,
#  'top round': 1,
#  'Commisions': 1,
#  'Open': 14,
#  'Open Commisions': 1,
#  '50% off': 2,
#  'biseuxal': 1,
#  'acceptance': 15,
#  'society': 6,
#  'A change that is needed': 2,
#  'A step': 1,
#  'Act now': 2,
#  'Assurance': 2,
#  'Attitude': 3,
#  'Believe': 2,
#  'Blessing': 1,
#  'Bold Confidence in God': 2,
#  'bold step': 1,
#  'Choice': 3,
#  'Commitment': 1,
#  'Actions': 1,
#  'Battle': 11,
#  'Be bold': 1,
#  'Be yourself': 1,
#  'Bold s step': 1,
#  'Braveness': 1,
#  'apk': 6,
#  'App': 23,
#  'WhatsApp': 280,
#  'sağlıklı': 2,
#  'psychotherapy': 2,
#  'counseling': 17,
#  'whatsapp': 690,
#  'kişisel': 1,
#  'basarkansay': 2,
#  'therapist': 6,
#  'mylife': 2,
#  'dr': 3,
#  'aile': 2,
#  'psikolog': 2,
#  'mutluluk': 3,
#  'ekremçulfa': 2,
#  'psikoterapi': 2,
#  'öfkeli': 2,
#  'therapy': 32,
#  'pedagog': 2,
#  'öfkenöbetleri': 2,
#  'what': 2,
#  'kaliforniya': 2,
#  'evlilik': 2,
#  'economia': 3,
#  'geraçãosolar': 3,
#  'empresa': 6,
#  'consultoria': 5,
#  'fotovoltaico': 3,
#  'viável': 3,
#  'fatura': 3,
#  'comoeconomizarenergia': 3,
#  'reduçãodecustos': 3,
#  'energia': 3,
#  'инфроструктура': 1,
#  'sprüche': 3,
#  'verliebt': 2,
#  'zitat': 2,
#  'thoughts': 7,
#  'texte': 2,
#  'freunde': 2,
#  'mädchen': 2,
#  'gedanken': 2,
#  'happy': 150,
#  'glücklich': 2,
#  'traurig': 2,
#  'boysayingzz': 2,
#  'vergessen': 2,
#  'gefuehl': 2,
#  'denken': 2,
#  'spruch': 2,
#  'schlaf': 2,
#  'feed': 45,
#  'spruchdestages': 2,
#  'zitate': 2,
#  'sad': 12,
#  'verloren': 2,
#  '30032018': 2,
#  'spiel': 2,
#  'freund': 2,
#  'text': 113,
#  'nachdenken': 2,
#  'sauer': 2,
#  'bild': 2,
#  'buenosdias': 5,
#  'cyl': 1,
#  'felizfindesemana': 1,
#  'delisvallradio': 1,
#  'música': 2,
#  'dance': 68,
#  'house': 240,
#  'felizsábado': 1,
#  'valladolid': 1,
#  'españa': 9,
#  'pop': 11,
#  'viber': 23,
#  'realestate': 683,
#  'sms': 29,
#  'reservation': 5,
#  'trippings': 3,
#  'hanapbahay101': 3,
#  'realinvestments': 3,
#  'hanapbahay': 3,
#  'laguna': 3,
#  'cavite': 4,
#  'movein': 1,
#  'tripping': 1,
#  'schedule': 10,
#  'clothing': 65,
#  'indianfashion': 16,
#  'beautiful': 191,
#  'makeup': 71,
#  'fashionblogger': 86,
#  'oxidisedjewellery': 3,
#  'imitationjewellery': 7,
#  'jewel': 125,
#  'girl': 239,
#  'onlineshoppingindia': 6,
#  'indianshopping': 3,
#  'onlineshopping': 158,
#  'women': 157,
#  'girls': 68,
#  'fashion': 582,
#  'eb5': 2,
#  'turkey': 24,
#  'email': 149,
#  'us': 15,
#  'metropical': 1,
#  'permanentresident': 1,
#  'istanbul': 36,
#  'turkish': 12,
#  'visa': 38,
#  'wechat': 3,
#  'inbox': 7,
#  'estudio': 1,
#  'mantenimiento': 2,
#  'calibración': 1,
#  'sala': 1,
#  'instrumentos': 1,
#  'músical': 1,
#  'mezcla': 2,
#  'audiovisual': 1,
#  'grabación': 1,
#  'producción': 1,
#  'avistudios': 1,
#  'vivo': 1,
#  'sonido': 1,
#  'ensayo': 1,
#  'movil': 1,
#  'TGIFriday': 1,
#  'Affordable': 66,
#  'Transporter': 1,
#  'LowestRates': 1,
#  'Shipping': 21,
#  'Budget': 5,
#  'Transport': 15,
#  'Quality': 52,
#  'Hauling': 1,
#  'BeatReputableCompetition': 1,
#  'affordable': 144,
#  'fresh coat of paint': 1,
#  'handy man services': 2,
#  'Honey-Do Services': 2,
#  'Interior Paint': 1,
#  'paint project': 1,
#  'painting': 80,
#  'residential painting': 1,
#  'all natural': 7,
#  'essential oils': 7,
#  'healing': 31,
#  'health': 562,
#  'holistic': 13,
#  'natural health': 1,
#  'non-toxic': 1,
#  'supplements': 9,
#  'wellness': 74,
#  'instafashion': 27,
#  'style': 616,
#  'amazing': 231,
#  'fashiondiaries': 47,
#  'ootd': 87,
#  'luxury': 1015,
#  'lipstick': 54,
#  'lookbook': 52,
#  'fashionstyle': 61,
#  'womenstyle': 14,
#  'itgirl': 5,
#  'girly': 4,
#  'loveyourself': 12,
#  'instastyles': 5,
#  'shopping': 936,
#  'pootd': 5,
#  'havetohaveit': 46,
#  'igstyle': 44,
#  'eveningdress': 8,
#  'classy': 57,
#  'trendy': 52,
#  'outfit': 60,
#  'love': 846,
#  'styletips': 11,
#  'styleoftheday': 5,
#  'Avoid Bankruptcy': 1,
#  'Corporate Financial Solutions': 1,
#  'JP Graci': 1,
#  'Paul Graci': 1,
#  'Chartered Insolvency': 1,
#  'JP Graci and Associates': 2,
#  'Credit Solutions Brantford': 1,
#  'Corporate Proposals': 1,
#  'Corporate Bankruptcy': 1,
#  'apply online': 4,
#  'degree Jobs': 2,
#  'Diploma Jobs': 1,
#  'Government Jobs': 3,
#  'latest jobs': 3,
#  'latest recruitment': 2,
#  'latest vacancies': 2,
#  'RPSC Recruitment': 1,
#  'apply for jobs': 1,
#  'WBSETCL Recruitment': 1,
#  'as seen on': 4,
#  'The Big Bang Theory': 1,
#  'RIP Carrie Fisher': 1,
#  'night owl redux': 1,
#  'the late show with stephen colbert': 1,
#  'lssc': 1,
#  'cats': 21,
#  'found on twitter': 1,
#  'bmx': 1,
#  'shoplocal': 68,
#  'charitytuesday': 13,
#  'bargain': 64,
#  'regram': 2,
#  'localbusiness': 31,
#  'dorset': 23,
#  'notforprofit': 2,
#  'bmxclothing': 1,
#  'backtothelab': 1,
#  'tee': 2,
#  'newtee': 1,
#  'thelabclothing': 1,
#  'thefrontskateshop': 1,
#  'thelab': 1,
#  'supportlocalbusiness': 4,
#  'apparel': 28,
#  'monochrome': 2,
#  'grey': 3,
#  'newtshirt': 1,
#  'treatyoself': 4,
#  'logotshirt': 1,
#  'bmxlife': 1,
#  'black': 41,
#  'moneyoff': 3,
#  'charity': 45,
#  'tshirt': 36,
#  'monochromeorgohome': 1,
#  'weymouth': 4,
#  'skateshop': 1,
#  'Adventures': 4,
#  'Adventures in Home Brewing': 1,
#  'all grain': 1,
#  'Beer Brewing System': 1,
#  'Best Price': 1,
#  'brewery': 4,
#  'brewrig': 1,
#  'deal': 236,
#  'home': 694,
#  'home brewery': 1,
#  'Home Brewing': 1,
#  'home brewing system': 1,
#  'homebrew': 1,
#  'homebrewing': 1,
#  'In': 3,
#  'Rig': 2,
#  'sale': 944,
#  'Bestattungshaus': 2,
#  'Billing': 14,
#  'DIN-zertifiziert': 1,
#  'in-zweiter-Generation': 1,
#  'Bundesverband-der-Bestatter': 1,
#  'Dresden': 2,
#  'Heidenau': 2,
#  'Pirna': 2,
#  'jederzeit-erreichbar': 2,
#  'Empathie': 2,
#  'Abmeldungen': 1,
#  'Hilfe': 1,
#  'Trauerfall': 2,
#  'Tod': 2,
#  'Vertrauen': 2,
#  'Respekt': 2,
#  'Video': 46,
#  'Bestattungsfachkräfte': 1,
#  'Bestattermeister': 1,
#  'Behördengängen': 1,
#  'celebrity': 81,
#  'usa': 85,
#  'uk': 119,
#  'singapore': 27,
#  'shoponline': 10,
#  'malaysia': 35,
#  'eidspecial': 3,
#  'soroposoblogger': 3,
#  'london': 152,
#  'wedding2018': 3,
#  'trending': 71,
#  'dennamiddleton': 3,
#  'bankruptcy': 30,
#  'call': 266,
#  'Borivali\xa0 Girls': 1,
#  'Call': 176,
#  'Women': 47,
#  'Nspire': 17,
#  'mlm': 30,
#  'womenshealth': 23,
#  'opportunity': 117,
#  'awareness': 34,
#  'patisserie': 4,
#  'fbacademygoa': 1,
#  'certified': 39,
#  'goa': 23,
#  'diplomedepatisserie': 1,
#  'chocolate': 22,
#  'foodybreaks': 1,
#  'cityandguilds': 1,
#  'pralines': 1,
#  'goabakers': 1,
#  'foodybreaksgoa': 1,
#  'processor': 1,
#  'refurbished': 5,
#  'interiordesign': 187,
#  'phoblographer': 3,
#  'photographers': 26,
#  'freelance': 17,
#  'tog': 3,
#  'photographer': 21,
#  'findingyourlight': 3,
#  'architectural': 5,
#  'canoneol': 3,
#  'canonusapro': 3,
#  'openfloorplan': 1,
#  'photography': 162,
#  'photog': 3,
#  'speedlite': 2,
#  'imagebyroamy': 3,
#  'realtor': 277,
#  'kellerwilliams': 14,
#  'photogs': 3,
#  'canon': 7,
#  'studios': 4,
#  'greatroom': 1,
#  'ppa': 3,
#  'professional': 68,
#  '600exrt': 2,
#  '5dsr': 3,
#  'beatmining': 3,
#  'productions': 3,
#  'togs': 3,
#  'dj': 22,
#  'dip': 3,
#  'pink': 19,
#  'landing': 4,
#  'birthdaygirl': 9,
#  'dc': 34,
#  'liquor': 5,
#  'streetstyle': 20,
#  'street': 9,
#  'pool': 48,
#  'bodypaint': 4,
#  'netflix': 7,
#  'mink': 5,
#  'top': 41,
#  'relationshipgoals': 6,
#  'naughty': 4,
#  'single': 15,
#  'ten': 3,
#  'party': 110,
#  'ship': 6,
#  'fire': 26,
#  'shake': 5,
#  'birthday': 104,
#  'naturallight': 1,
#  'landscape': 17,
#  'randrealty': 1,
#  'betterhomeandgarderns': 1,
#  'gatedcommunity': 2,
#  'kanye': 2,
#  'BUZZFEED': 1,
#  'Here039s': 1,
#  'Hotline': 61,
#  'Prevention': 208,
#  'Suicide': 6,
#  'Humanities': 1,
#  'INSTITUTE': 1,
#  'Issues': 2,
#  'Papers': 4,
#  'siddhesh_mohan_vaidya': 5,
#  'lights': 15,
#  '9623001100': 5,
#  'ambiencelighting': 5,
#  'ledlights': 12,
#  'event': 85,
#  'weddingsatalibag': 5,
#  'parlights': 5,
#  'hightlight': 5,
#  'ambience': 6,
#  '9029031100': 5,
#  'alibagweddingplanner': 5,
#  'floodlights': 5,
#  'utsavalibag': 5,
#  'alibagevents': 6,
#  'parcan': 5,
#  'postpartum': 8,
#  'aerobics': 7,
#  'womenfashion': 21,
#  'freedeliveryincbd': 7,
#  'workoutfit': 8,
#  'waistline': 7,
#  'belly': 9,
#  'kenya': 33,
#  'samedaydelivery': 18,
#  'outfits': 14,
#  'workingmom': 10,
#  'slimming_corset': 7,
#  'shape': 16,
#  'babyfat': 7,
#  'mavazi': 7,
#  'feelgoodfriday': 3,
#  'countrywidedelivery': 13,
#  'shapewearkenya': 7,
#  'location': 109,
#  'waisttrainer': 7,
#  'lovehandles': 8,
#  'pregnant': 13,
#  'nairobi': 21,
#  'kitambi': 7,
#  'friday': 54,
#  'gym': 63,
#  'doctor on call': 29,
#  'doctors': 44,
#  'doctors on call': 29,
#  '91-9205903598': 1,
#  'company': 63,
#  'delhi': 65,
#  'development': 74,
#  'india': 346,
#  'web': 55,
#  'website': 302,
#  'wordpress': 86,
#  'adventure': 67,
#  'books': 162,
#  'wattpad': 68,
#  'amreading': 63,
#  'sexy': 55,
#  'models': 17,
#  'dating': 7,
#  'relationship': 11,
#  'woman': 26,
#  'female': 20,
#  'housewife': 1,
#  'hot': 46,
#  'sizziling': 2,
#  'Independent': 11,
#  'agency': 40,
#  'money': 427,
#  'argentina': 7,
#  'tijuana': 4,
#  'fit': 59,
#  'chance': 15,
#  'chile': 9,
#  'emprededores': 1,
#  'tx': 9,
#  'empresarios': 1,
#  'networking': 109,
#  'sonora': 1,
#  'bootcampfitnessgym': 1,
#  'fitness': 649,
#  'salud': 13,
#  'sinaloa': 1,
#  'finanzas': 4,
#  'dinero': 3,
#  'entrepreneur': 242,
#  'emprende': 4,
#  'fitmom': 4,
#  'keepgoing': 1,
#  'worldwide': 397,
#  'networkmarketing': 5,
#  'sandiego': 32,
#  'justdoit': 8,
#  'colombia': 21,
#  'teamwork': 21,
#  'coachmoniquezj': 3,
#  'dad': 4,
#  'Buy Audi': 710,
#  'buy on credit': 710,
#  'cheap': 777,
#  'amazon prime': 2,
#  'customer service': 4,
#  'phone number': 16,
#  'cancellation': 5,
#  'refund': 14,
#  'membership': 27,
#  'amazon': 29,
#  'prime': 8,
#  'customer': 37,
#  'service': 223,
#  'amazon prime customer': 1,
#  'psychics': 4,
#  'phone psychic': 3,
#  'call a psychic': 4,
#  'call a reader': 4,
#  'call us': 8,
#  'psychic medium': 1,
#  'Psychic': 5,
#  'psychic reader': 3,
#  'psychic ability': 2,
#  'psychic reading': 3,
#  'help': 120,
#  'stress relief': 1,
#  'forecasting': 2,
#  'love psychic': 3,
#  'clairvoyant': 9,
#  'we are different': 1,
#  'new client': 1,
#  'special': 210,
#  'marketing': 744,
#  'contact': 182,
#  'prominent business solutions': 1,
#  'jacksonville': 11,
#  'florida': 122,
#  'hiring': 1035,
#  'psychic': 65,
#  'reader': 5,
#  'why': 3,
#  'phone': 106,
#  'phone psychic reading': 1,
#  'relationship psychic': 1,
#  'twin flames': 1,
#  'soulmates': 2,
#  'lonely': 4,
#  'forecasting reading': 1,
#  'issues': 8,
#  'insight': 1,
#  'friend': 9,
#  'we are here': 1,
#  'we love to help': 2,
#  'wow': 157,
#  'call now': 1,
#  'immaculate': 1,
#  'homesweethome': 41,
#  'berkshire hathaway': 1,
#  'good to know': 1,
#  'textme': 6,
#  'mesages': 1,
#  'Adam CHAT': 5,
#  'CHAT free trial': 5,
#  'free trial': 9,
#  'be careful': 1,
#  'misha collins': 1,
#  'not misha': 1,
#  'gishwhes': 1,
#  'stay safe': 1,
#  'destiel': 1,
#  'see': 3,
#  'check': 29,
#  'best clinic': 3,
#  'San Diego': 2,
#  'California': 52,
#  'egg donation': 1,
#  'contact us': 4,
#  'health care': 11,
#  'blog': 24,
#  'Contact us': 1,
#  'diamond engagement rings': 1,
#  'jewellery shops in birmingham': 1,
#  'diamond wedding rings': 1,
#  'birmingham jewellery quarter': 1,
#  'coffeepainting': 3,
#  'compare': 13,
#  'galleryjib': 3,
#  'tokyo': 34,
#  'minoriwarabisako': 3,
#  'nakameguro': 3,
#  'minor_i': 3,
#  'comparison': 2,
#  'submission': 12,
#  'skydive': 1,
#  'airbnb': 16,
#  'guests': 5,
#  'awesome': 20,
#  'collect': 8,
#  'thankyou': 75,
#  'skydiveperris': 1,
#  'skydiving': 1,
#  'gift': 84,
#  'compare rates': 2,
#  'excellent calgary auto': 2,
#  'rates annually': 1,
#  'excellent calgary': 1,
#  'bow valley insurance': 1,
#  'compare insurance rates': 1,
#  'insurance broker': 1,
#  'insurance provider': 1,
#  'insurance rates': 1,
#  'bow valley': 2,
#  'insurance policies': 1,
#  'auto insurance rates': 2,
#  'calgary auto': 1,
#  'auto insurance broker': 2,
#  'auto insurance': 2,
#  'insurance rates annually': 2,
#  'Cash Bonus': 1,
#  'ibet malaysia': 1,
#  'malaysia online casino': 1,
#  'rebate 0.75%': 1,
#  'host': 5,
#  'magic': 11,
#  'executive': 8,
#  'fortune': 4,
#  'casino': 133,
#  'witchcraft': 4,
#  'deathmetal': 4,
#  'film': 28,
#  'hell': 4,
#  'occult': 3,
#  'bookstagram': 8,
#  'heavymetal': 4,
#  'read': 6,
#  'artist': 63,
#  'publisher': 3,
#  'selfie': 33,
#  'drugs': 9,
#  'artisan': 9,
#  'sin': 3,
#  'bloody': 3,
#  'witchy': 4,
#  'zombie': 3,
#  'author': 36,
#  'happyhour': 11,
#  'hbcu': 4,
#  'rock': 16,
#  'literature': 54,
#  'reallife': 10,
#  'fridaynight': 10,
#  'WinfordManila': 1,
#  'WinfordHotel': 1,
#  'Winford': 1,
#  'Hotel': 73,
#  'Casino': 21,
#  'Staycation': 16,
#  'SanLazaro': 1,
#  'ChoiGarden': 1,
#  'CopadeManila': 1,
#  'congratulations': 20,
#  'illustration': 17,
#  'cute': 96,
#  'draw': 9,
#  'animallovers': 1,
#  'etsyshop': 5,
#  'etsyfinds': 5,
#  'etsy': 25,
#  'animals': 10,
#  'instagood': 193,
#  'cutefox': 1,
#  'twochubbas': 1,
#  'baby': 45,
#  'etsybestsellers': 1,
#  'fox': 4,
#  'digitaldrawing': 1,
#  'drawing': 29,
#  'fmentertainment': 1,
#  'djfmexperience': 1,
#  'youhadmeatowusu': 1,
#  'theonlywayisup': 4,
#  'credit': 299,
#  'arbitraging': 4,
#  'blameforex': 4,
#  'crypto': 107,
#  'success': 223,
#  'yoga': 51,
#  'cryptomemes': 6,
#  'fitlife': 11,
#  'successful': 26,
#  'teleminer': 4,
#  'bitcoins': 49,
#  'sports': 42,
#  'africanwomenentrepreneurs': 5,
#  'prosperity': 6,
#  'cloud': 24,
#  'wealth': 111,
#  'blockchain': 142,
#  'value': 20,
#  'p3d': 4,
#  'ghostpick': 3,
#  'entrepreneurship': 42,
#  'bullish': 6,
#  'hardwork': 22,
#  'bear': 7,
#  'motivation': 331,
#  'passive': 4,
#  'personal': 37,
#  'working': 25,
#  'corporate': 48,
#  'loans': 72,
#  'inquiry': 8,
#  'shelf': 2,
#  'cfo': 3,
#  'aged': 2,
#  'businesscreditline': 2,
#  'personallineofcredit': 2,
#  'start': 6,
#  'unsecured': 2,
#  'best': 104,
#  'funding': 102,
#  'no': 17,
#  'business': 1311,
#  'bad': 3,
#  'instafood': 113,
#  'papavincepizza': 97,
#  'pizzas': 103,
#  'bestfriend': 2,
#  'pizzaparty': 101,
#  'pizza🍕': 97,
#  'pizza': 175,
#  'brocku': 96,
#  'thorold': 97,
#  'foodie': 216,
#  'debit': 102,
#  'food': 302,
#  'foodlover': 102,
#  'dailypizza': 97,
#  'pizzanight': 97,
#  'instapizza': 97,
#  'pizzalover': 104,
#  'pizzeria': 98,
#  '🍕': 97,
#  'pizzagram': 98,
#  'foodblogger': 114,
#  'foodporn': 157,
#  'pizzatime': 102,
#  'pizzabox': 97,
#  'pizzaporn': 97,
#  'eeeeeats': 12,
#  'pizzaman': 97,
#  'judionline': 47,
#  'judi': 23,
#  'judibola': 2,
#  'casinoonline': 11,
#  'casino198': 1,
#  'taruhanbola': 2,
#  'pialadunia2018': 1,
#  'agenbola': 20,
#  'agenjudi': 30,
#  'sportsbook': 36,
#  'poker': 35,
#  'pokeronline': 20,
#  'dominoqq': 2,
#  'bandarjudi': 2,
#  'bandarbola': 2,
#  'bandarcapsa': 1,
#  'capsa': 2,
#  'gone': 1,
#  'month': 3,
#  'april': 1,
#  'want': 4,
#  'fico': 30,
#  'win': 89,
#  'interest': 14,
#  'low': 6,
#  'i': 4,
#  'your': 22,
#  'to': 383,
#  'almost': 1,
#  'score': 16,
#  'everybody': 2,
#  'rate': 6,
#  'videogame': 53,
#  'deals': 193,
#  'video game': 52,
#  'video games': 56,
#  'book': 143,
#  'debt': 79,
#  'private': 20,
#  'Direct Marketing': 19,
#  'HABAUTO': 1,
#  'EngineDiagnostics': 5,
#  'Diagnostics': 26,
#  'DiagnosticService': 1,
#  'HamiltonMechanic': 1,
#  'HamiltonAlignment': 1,
#  'EngineTrouble': 1,
#  'EngineIssues': 1,
#  'cash': 129,
#  'SwagBucks': 2,
#  'fast cash': 6,
#  'earn extra cash': 2,
#  'earn cash': 3,
#  'Easy Cash': 2,
#  'make money': 11,
#  'easy money': 6,
#  'make money from home': 6,
#  'Money Online': 2,
#  'paypal': 33,
#  'sephora': 3,
#  'Gift Card': 2,
#  'Vegas': 74,
#  'guarantee': 11,
#  'perry mi': 1,
#  'guaranteed': 10,
#  'reviews': 9,
#  'star': 6,
#  'potatochips': 2,
#  'lays kettle cooked': 1,
#  'crunch time': 1,
#  'free sample': 1,
#  'mymagazinesharing': 1,
#  'Kroger': 1,
#  'sharemarket': 27,
#  'stock market': 15,
#  'stock market news': 1,
#  'latest news': 16,
#  'testimonial': 9,
#  'satisfaction': 22,
#  'client': 9,
#  'equity tips': 6,
#  'forex': 66,
#  'share market tips': 8,
#  'trading tips': 1,
#  'create free website': 1,
#  'free website': 2,
#  'free domain': 1,
#  'How to create website': 1,
#  'website design': 1,
#  'website builder': 1,
#  'ecommerce website': 1,
#  'catchbeachclub': 1,
#  'get': 47,
#  'ladiesnight': 13,
#  'night': 13,
#  'champagne': 6,
#  'ladynightphuket': 1,
#  'latin': 1,
#  'phuketnightlife': 1,
#  'enjoy': 32,
#  'thursday': 14,
#  'girlsnightout': 3,
#  'rose': 9,
#  'djhenryknowles': 1,
#  'beach': 53,
#  'bangkok': 19,
#  'thailand': 45,
#  'phuket': 4,
#  'tonight': 8,
#  'ladies': 300,
#  'repost': 147,
#  'salsaphuket': 1,
#  'magnum': 1,
#  'salsathailand': 1,
#  'MAP': 1,
#  'pedophile': 1,
#  'psychiatry': 1,
#  'medication': 8,
#  'minor': 1,
#  'children': 49,
#  "don't": 1,
#  'bone': 2,
#  'little': 9,
#  'boys': 6,
#  'you': 13,
#  "aren't": 1,
#  'oppressed': 1,
#  "you're": 1,
#  'ill': 1,
#  'or': 25,
#  'latest version download': 1,
#  'mac download': 1,
#  'online 2018': 1,
#  'precraced download': 2,
#  'buy': 288,
#  'freeadd': 1,
#  'linux mint': 1,
#  'repack jar': 1,
#  'repack jar linux 2018': 2,
#  'repack rar 2018': 1,
#  'sentences': 1,
#  'look': 16,
#  'facebook': 430,
#  'here': 31,
#  'english': 61,
#  'theladydontmind': 1,
#  'replies': 1,
#  'Here': 2,
#  'its like $30': 1,
#  'im waiting til i get paid': 1,
#  'linux file permissions download': 1,
#  'linux unzip': 1,
#  'repack news download': 1,
#  'repack rar': 3,
#  'coupon': 38,
#  'lot': 6,
#  'two': 3,
#  '2018': 51,
#  'guide download': 1,
#  'kickass download': 1,
#  'linux unzip tar.gz 2018': 1,
#  'online job': 1,
#  'typing job': 1,
#  'work online': 1,
#  'easy ways to get money': 1,
#  'get paid': 1,
#  'view ads': 1,
#  'type ads': 1,
#  'gift certificate': 10,
#  'adagio tea': 7,
#  'blue moon': 1,
#  'fullmoon': 5,
#  'tea': 25,
#  'adagio teas': 6,
#  'moon': 19,
#  'witches': 2,
#  'moon spells': 1,
#  'tea spells': 1,
#  'spells': 3,
#  'herbal': 13,
#  'herbal teas': 1,
#  'tea time': 2,
#  'adagio': 7,
#  'free tea': 1,
#  'gift card': 3,
#  'shut up fox': 1,
#  'Frontrow': 13,
#  'NiteFlirt': 1372,
#  'NoKavanaugh': 18,
#  'SaturdayAfternoonShow': 3,
#  'RadioActive': 2,
#  'VirtualPA': 1,
#  'VirtualAssistant': 2,
#  'AdminHelp': 1,
#  'shop': 95,
#  'outdoors': 12,
#  'adventures': 2,
#  'fishing': 25,
#  'gifts': 61,
#  'Back Pain': 6,
#  'Neck Pain': 6,
#  'Pain': 13,
#  'physical therapy': 6,
#  'physical therapy (medical specialty)': 6,
#  'physio': 24,
#  'physiotherapist': 8,
#  'physiotherapist (profession)': 6,
#  'physiotherapy': 20,
#  'physiotherapy at home': 6,
#  'shoulder pain': 6,
#  'Mission2030': 3,
#  'renewables': 1,
#  'mobility': 8,
#  'Greenstorm': 1,
#  'aim global': 4,
#  'make money online': 15,
#  'income': 51,
#  'home based': 1,
#  'parttime': 7,
#  'network marketing': 5,
#  ...}
